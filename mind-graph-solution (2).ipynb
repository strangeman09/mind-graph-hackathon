# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_club=pd.read_csv('../input/mind-graph/Clubs_data.csv')
df_club.head()
# Out:
#   Club_Name            Name           Event         Role
# 0    club_3       Darien Ma  club_3_event_2  Participant
# 1    club_2    Sege Schrock  club_2_event_1  Participant
# 2    club_3      Alison bci  club_3_event_2  Participant
# 3    club_1  kiara jauregui  club_1_event_1  Participant
# 4    club_2       Tete Buim  club_2_event_3  Participant

# %%
df_club.isnull().sum()
# Out:
# Club_Name    0
# Name         0
# Event        0
# Role         0
# dtype: int64

# %%
df_club.shape
# Out:
# (1046, 4)

# %%
df_club['Name'].nunique()
# Out:
# 987

# %%
df_meta=pd.read_csv('../input/mind-graph/Metadata.csv')
df_meta.head()
# Out:
#               Name          ID
# 0    Annette Ahmed  18XJ1A0100
# 1   Zachery Clancy  18XJ1A0101
# 2   Jaquelin Duran  18XJ1A0102
# 3  Orlando Clemens  18XJ1A0103
# 4   Dorothy Mayhew  18XJ1A0104

# %%
df_meta.isnull().sum()
# Out:
# Name    0
# ID      0
# dtype: int64

# %%
print(df_meta['Name'].nunique())
df_meta.shape
# Out:
# 500
# (500, 2)

# %%
df_org=pd.read_csv('../input/mind-graph/Organisers_In_Fests.csv')
df_org.head()
# Out:
#   Fest_Name                Name         Role
# 0    fest_2       Stcerr Hbmond  organiser_2
# 1    fest_2         Ayliwn Slks  organiser_6
# 2    fest_2  Sebestien Hickjman  organiser_7
# 3    fest_2     Grechen Chlewsn  organiser_8
# 4    fest_1            Evelin B  organiser_1

# %%
print(df_org['Name'].nunique())
df_org.shape
# Out:
# 20
# (20, 3)

# %%
df_org['Name']
# Out:
# 0          Stcerr Hbmond
# 1            Ayliwn Slks
# 2     Sebestien Hickjman
# 3        Grechen Chlewsn
# 4               Evelin B
# 5      leniez Gilbertson
# 6       mRiver Flipcieno
# 7               Leona Ca
# 8              Ay Kehnei
# 9          tbdulelh Hors
# 10             S Stephon
# 11         Prxry Pefryen
# 12             Derii Dai
# 13                    RB
# 14            Jordi Taem
# 15                    AM
# 16      Reshawn Balsdeas
# 17      Bline Mckesnezie
# 18        Ashanti John K
# 19        zoie mcdermott
# Name: Name, dtype: object

# %%
df_org.isnull().sum()
# Out:
# Fest_Name    0
# Name         0
# Role         0
# dtype: int64

# %%
df_part=pd.read_csv('../input/mind-graph/Participants_In_Fests.csv')
df_part.head()
# Out:
#   Fest_Name            Name            Event
# 0    fest_1      JenapRowli   fest_1_event_9
# 1    fest_1   Credyj Duenas   fest_1_event_4
# 2    fest_2  Jequqlin Duran   fest_2_event_1
# 3    fest_1  Keiyah widalgo   fest_1_event_4
# 4    fest_2   Elaine John S  fest_2_event_15

# %%
print(df_part['Name'].nunique())
df_part.shape
# Out:
# 4060
# (4769, 3)

# %%
df_part.isnull().sum()
# Out:
# Fest_Name    0
# Name         0
# Event        0
# dtype: int64

# %%
#Import
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
df1_names = list(df_meta['Name'].unique())
df2_names = list(df_org['Name'].unique())

# %%
def match_names(name, list_names, min_score=0):
    max_score = -1
    max_name = ''
    for x in list_names:
        score = fuzz.partial_ratio(name, x)
        if (score > min_score) & (score > max_score):
            max_name = x
            max_score = score
    return (max_name, max_score)

# %%
names = {}
for x in df2_names:
    match = match_names(x, df1_names, 45)
    if match[1] >=45:
        name =  str(match[0]) 
        names[x]=name

names
# Out:
# {'Stcerr Hbmond': 'Starr Hammond',
#  'Ayliwn Slks': 'Aylin Seals',
#  'Sebestien Hickjman': 'Sebastien Hickman',
#  'Grechen Chlewsn': 'Gretchen Clawson',
#  'Evelin B': 'Evelin Bradley',
#  'leniez Gilbertson': 'Delanie Gilbertson',
#  'mRiver Flipcieno': 'River Feliciano',
#  'Leona Ca': 'Leona Cabral',
#  'Ay Kehnei': 'Aya Kennedy',
#  'tbdulelh Hors': 'Abdullah Horst',
#  'S Stephon': 'Stephon Smoot',
#  'Prxry Pefryen': 'Perry Perryman',
#  'Derii Dai': 'Daria Daily',
#  'RB': 'Genevieve Ratliff',
#  'Jordi Taem': 'Jordi Tam',
#  'AM': 'Annette Ahmed',
#  'Reshawn Balsdeas': 'Rashawn Balderas',
#  'Bline Mckesnezie': 'Blaine Mckenzie',
#  'Ashanti John K': 'Ashanti Koenig',
#  'zoie mcdermott': 'Zoie McDermott'}

# %%
df_org.Name = df_org.Name.map(names)

# %%
df_org['Name']
# Out:
# 0          Starr Hammond
# 1            Aylin Seals
# 2      Sebastien Hickman
# 3       Gretchen Clawson
# 4         Evelin Bradley
# 5     Delanie Gilbertson
# 6        River Feliciano
# 7           Leona Cabral
# 8            Aya Kennedy
# 9         Abdullah Horst
# 10         Stephon Smoot
# 11        Perry Perryman
# 12           Daria Daily
# 13     Genevieve Ratliff
# 14             Jordi Tam
# 15         Annette Ahmed
# 16      Rashawn Balderas
# 17       Blaine Mckenzie
# 18        Ashanti Koenig
# 19        Zoie McDermott
# Name: Name, dtype: object

# %%
df_org['Name'].nunique()
# Out:
# 20

# %% [markdown]
# repeating the above process for df_part and df_club

# %%
df3_names = list(df_part['Name'].unique())
names = []
for x in df3_names:
    match = match_names(x, df1_names, 45)
    if match[1] >= 45:
        name = ((  str(x), str(match[0])  ))
        names.append(name)
name_part_dict = dict(names)

# %%
name_part_dict
# Out:
# {'JenapRowli': 'Jayna Rowley',
#  'Credyj Duenas': 'Candy Duenas',
#  'Jequqlin Duran': 'Jaquelin Duran',
#  'Keiyah widalgo': 'Kaliyah Hidalgo',
#  'Elaine John S': 'Elaine Sell',
#  'Koljte Roend': 'Kolten Roland',
#  'Sebestn sHickman': 'Sebastien Hickman',
#  'GC': 'Zachery Clancy',
#  'JevonteTrevibno': 'Javonte Trevino',
#  'Luca S': 'Luca Sanders',
#  'Iebelm Perals': 'Isabell Perales',
#  'Mcknzie Frn': 'Mckenzie Finn',
#  'HlyStroum': 'Holly Strom',
#  'Monric Grabowhsy': 'Monica Grabowski',
#  'Yesminez Sdler': 'Yasmine Sadler',
#  'eyleigh Ktoenig': 'Kayleigh Koenig',
#  'Shawn Ka': 'Shawn Kay',
#  'Luiz McLxeuglin': 'Luiz McLaughlin',
#  'Thee Mcoloud': 'Thea McCloud',
#  'Elaine S': 'Elaine Sell',
#  'vRlehul Va': 'Rahul Vera',
#  'Judikt Cok': 'Judith Crook',
#  'Yisrojal Stor': 'Yisroel Storm',
#  'gerald arreola': 'Gerald Arreola',
#  'Shawn John K': 'Shawn Kay',
#  'uoedyBeder': 'Kody Bader',
#  'CeylaRicnon': 'Cayla Rincon',
#  'Gissase Thorntn': 'Gisselle Thornton',
#  'Sereniy Cyestilo': 'Serenity Castillo',
#  'DoiencMediuna': 'Dorian Medina',
#  'gobies Wheler': 'Tobias Wheeler',
#  'Deshapun Sers': 'Dashaun Sears',
#  'Hudson Gyuhmen': 'Hudson Guzman',
#  'Heis Pafish': 'Harris Parish',
#  'DC': 'Zachery Clancy',
#  'SemnjanakCornwel': 'Sanjana Cornwell',
#  'Glen cDrepr': 'Glen Draper',
#  'M Luiz': 'Finn Mullins',
#  'Cendxac Barkl': 'Candace Barkley',
#  'ashtyn inman': 'Ashtyn Inman',
#  'Hermony McDermoq': 'Harmony McDermott',
#  'Evliny Bredli': 'Evelin Bradley',
#  'zKelsheSegure': 'Kelsie Segura',
#  'Karla John F': 'Karla Frank',
#  'Adaklie Heni': 'Adeline Henry',
#  'SS': 'Daysha Sapp',
#  'Izeih qBaraa': 'Izaiah Barraza',
#  'Ansley John W': 'Ainsley Clinton',
#  'Heley Garcib': 'Harley Garibay',
#  'Netdhaly Laoaie': 'Nathaly Lavoie',
#  'Maxim S': 'Maxim Simonson',
#  'BB': 'Branson Harman',
#  'Keith De': 'Keith Dempsey',
#  'Kendqirck Gevin': 'Kendrick Gavin',
#  'Codey John L': 'Codey Lyon',
#  'Alyive Kidwnel': 'Alivia Kidwell',
#  'Jkquelint Duran': 'Jaquelin Duran',
#  'Blaine John M': 'Blaine Mckenzie',
#  'Bredy Grism': 'Brady Grissom',
#  'Armen yGriwld': 'Arman Griswold',
#  'YwisroalaStorm': 'Yisroel Storm',
#  'Roxena Toni': 'Roxanna Toney',
#  'Denise egyucre': 'Denise Segura',
#  'Isabell John P': 'Isabell Perales',
#  'Jeckeline Brijoe': 'Jackeline Briscoe',
#  'ljise Negrete': 'Elisa Negrete',
#  'Chzerlote Lorneo': 'Charlotte Lorenzo',
#  'ry Lakgird': 'Barry Laird',
#  'CC': 'Zachery Clancy',
#  'Trent Ha': 'Trent Hartmann',
#  'tphomn zSmot': 'Stephon Smoot',
#  'Efrein Tuiclo': 'Efrain Trujillo',
#  'Cedace Brkili': 'Candace Barkley',
#  'nEileine el': 'Elaine Sell',
#  'alvin hayden': 'Alvin Hayden',
#  'Kebmron Bilingsli': 'Kamron Billingsley',
#  'Celan Ienfante': 'Caelan Infante',
#  'Cndgace Barki': 'Candace Barkley',
#  'nMuonice Grabows': 'Monica Grabowski',
#  'Gine Gri': 'Jaime Grimes',
#  'Kristeanl Janse': 'Kristian Jansen',
#  'Cuen Celaregse': 'Cullen Calabrese',
#  'Jesegnie Peles': 'Jessenia Perales',
#  'Briza Bu': 'Briza Buford',
#  'Jevmison Oorio': 'Jamison Osorio',
#  'R Yosef': 'Yousef Luttrell',
#  'Luca John S': 'Luciano Sims',
#  'Gretcen Clpewson': 'Gretchen Clawson',
#  'rKao Grisfn': 'Brady Grissom',
#  'Sasha S': 'Sasha Sweat',
#  'Ceylsan Rinc': 'Cayla Rincon',
#  'Mefim zSimoson': 'Maxim Simonson',
#  'Delas cBal': 'Dallas Ball',
#  'Cerl Cormixer': 'Carlo Cormier',
#  'Betsy Bl': 'Betsy Blake',
#  'Roxanna To': 'Roxanna Toney',
#  'jaylan conway': 'Jaylan Conway',
#  'Trent eratman': 'Trent Hartmann',
#  'Ayli Seels': 'Aylin Seals',
#  'LeceyVnaldez': 'Lacey Valdez',
#  'Diego Sh': 'Diego Shanks',
#  'M Rafael': 'Rafael Mansfield',
#  'DS': 'Jaquelin Duran',
#  'Colden Peace': 'Coleman Peace',
#  'Zechery dSchader': 'Zachery Schrader',
#  'Tren Hertmamn': 'Trent Hartmann',
#  'Hes Payurish': 'Harris Parish',
#  'Kenya Pa': 'Kenya Patrick',
#  'Cqrlo Crmier': 'Carlo Cormier',
#  'Atnydees Byers': 'Andreas Byers',
#  'DametriusHgutchison': 'Demetrius Hutchison',
#  'eyojb Kaufman': 'Jaycob Kauffman',
#  'CL': 'Zachery Clancy',
#  'YousafLttwrel': 'Yousef Luttrell',
#  'JcxklyncSaenz': 'Jacklyn Saenz',
#  'dGaoffryq Ridle': 'Geoffrey Riddle',
#  'Anthony Ll': 'Anthony Llamas',
#  'B Kody': 'Johnnie Moody',
#  'Aigele Sahnder': 'Abigayle Sander',
#  'Finn M': 'Finn Mullins',
#  'KW': 'Keyara Camacho',
#  'Rhienan Swift': 'Rhiannon Swift',
#  'eqcey Vaaldez': 'Lacey Valdez',
#  'Hema Camswevl': 'Hamza Caswell',
#  'S Kolby': 'Clifton Colby',
#  'Itsebel Perales': 'Isabell Perales',
#  'Evelin B': 'Evelin Bradley',
#  'Payton rshford': 'Peyton Ashford',
#  'esnifse erden': 'Denisse Warden',
#  'Natorf Light': 'Nestor Light',
#  'Keshewn Sein': 'Keshawn Stein',
#  'Shaldon Erscrt': 'Sheldon Ernst',
#  'RV': 'Genevieve Ratliff',
#  'ucte Sandes': 'Luca Sanders',
#  'Gary John P': 'Henry Johansen',
#  'eYtsic Rucker': 'Yessica Rucker',
#  'Reshawn Balderaws': 'Rashawn Balderas',
#  'charlotte lorenzo': 'Charlotte Lorenzo',
#  'edise wDecker': 'Madisen Decker',
#  'Tuobies Whele': 'Tobias Wheeler',
#  'sasha sweat': 'Sasha Sweat',
#  'MF': 'Dorothy Mayhew',
#  'Jeycob Kaffan': 'Jaycob Kauffman',
#  'Ncthal Lavoie': 'Nathaly Lavoie',
#  'Ireland Be': 'Ireland Bernier',
#  'S Maxim': 'Maximilian McGraw',
#  'G Nataly': 'Natalya Garvin',
#  'Quwitn Whiting': 'Quinten Whiting',
#  'Chrlote orbemnzo': 'Charlotte Lorenzo',
#  'RD': 'Jaquelin Duran',
#  'VD': 'Jaquelin Duran',
#  'Gwendolyn John B': 'Gwendolyn Bain',
#  'Adrez Graf': 'Adrian Graff',
#  'Trent Hrtmaxa': 'Trent Hartmann',
#  'Holy Strro': 'Holly Strom',
#  'Debre Clbvenger': 'Debra Clevenger',
#  'Bets Bleke': 'Betsy Blake',
#  'candy duenas': 'Candy Duenas',
#  'uzdson Guzmen': 'Hudson Guzman',
#  'Kany Greifi': 'Keon Griffin',
#  'KH': 'Keyara Camacho',
#  'diego shanks': 'Diego Shanks',
#  'EA': 'Annette Ahmed',
#  'AnnaatemAhmed': 'Annette Ahmed',
#  'Gereel Areola': 'Gerald Arreola',
#  'Genero butlver': 'Genaro Culver',
#  'kyurt Muguie': 'Kurt Munguia',
#  'Doerie Medina': 'Dorian Medina',
#  'Getchehn Cleson': 'Gretchen Clawson',
#  'Daisy John B': 'Daisy Burton',
#  'Leone Cabeal': 'Leona Cabral',
#  'Herman Tu': 'Herman Turley',
#  'ellibe Everet': 'Kallie Everett',
#  'Keliyahe Hidlgo': 'Kaliyah Hidalgo',
#  'Yesi Ruckter': 'Yessica Rucker',
#  'Ceilyn gSwar': 'Cailyn Seward',
#  'zNelelyCovi': 'Nallely Covey',
#  'Tharoan Stroud': 'Theron Stroud',
#  'Yessica John R': 'Yessica Rucker',
#  'W Kurt': 'Kurt Wilkins',
#  'Ryecn Czker': 'Ryann Coker',
#  'Hudson G': 'Hudson Guzman',
#  'yuenCoker': 'Kaycee Coker',
#  'Lcey Valdoez': 'Lacey Valdez',
#  'zZecaryNaylor': 'Zackary Naylor',
#  'Ansuly Wilkes': 'Ansley Wilkes',
#  'Ketryn Naranjzo': 'Kathryn Naranjo',
#  'Kenen tone': 'Keenan Stone',
#  'Nigal uj': 'Nigel Bunn',
#  'Mexieusf ish': 'Maximus Fish',
#  'Jelyl Cyr': 'Nallely Covey',
#  'V Jada': 'Santiago Nadeau',
#  'Gaoffareya Ridl': 'Geoffrey Riddle',
#  'Netalyg Gmaham': 'Nataly Graham',
#  'yAwrmen Grisod': 'Arman Griswold',
#  'Saphnon Burnet': 'Stephon Burnett',
#  'Theron John S': 'Theron Stroud',
#  'Adnnebelle Mili': 'Annabelle Malloy',
#  'eefh Spjangler': 'Aleah Spangler',
#  'CR': 'Zachery Clancy',
#  'CI': 'Zachery Clancy',
#  'Kamron B': 'Kamron Billingsley',
#  'Abrien gDelarosa': 'Abrianna Delarosa',
#  'Jovhnpeu Wing': 'Johnpaul Wing',
#  'Denisela oo': 'Denise Minor',
#  'Tjent Hertmagn': 'Trent Hartmann',
#  'Ainslaty Clinton': 'Ainsley Clinton',
#  'Sasha Sw': 'Sasha Sweat',
#  'Mrtielz Shearer': 'Mariel Shearer',
#  'Keshen Steeimn': 'Keshawn Stein',
#  'Colin John H': 'Colin Hughes',
#  'ToebisesWheer': 'Tobias Wheeler',
#  'D Yasmine': 'Yasmine Dunning',
#  'M Dorian': 'Dorian Medina',
#  'Derqel Clevenger': 'Debra Clevenger',
#  'peyton mast': 'Peyton Mast',
#  'pMelika Garer': 'Malika Garber',
#  'Harmony Mc': 'Harmony McDermott',
#  'S Nathanial': 'Nathanial Sampson',
#  'Deinie Werdan': 'Denisse Warden',
#  'pKaon Grinin': 'Keon Griffin',
#  'Malika Ga': 'Malika Garber',
#  'Yousaf xLttrel': 'Yousef Luttrell',
#  'B Makala': 'Makala Bruns',
#  'Helie Metzger': 'Halie Metzger',
#  'Perry P': 'Perry Perryman',
#  'shtytn Inmen': 'Ashtyn Inman',
#  'Maximus K': 'Maximus Kelly',
#  'Yessica Ru': 'Yessica Rucker',
#  'malika garber': 'Malika Garber',
#  'semaj plummer': 'Semaj Plummer',
#  'Gkenero Cvjer': 'Genaro Culver',
#  'Jonathon John L': 'Johnathon Leger',
#  'yeni Coer': 'Kaycee Coker',
#  'Mitchel Corcoen': 'Mitchel Corcoran',
#  'Dieg eShenks': 'Diego Shanks',
#  'Meximusk Fh': 'Maximus Fish',
#  'Heros Parissh': 'Harris Parish',
#  'abvyn Ewing': 'Devyn Ewing',
#  'Alee Sanglcer': 'Aleah Spangler',
#  'SH': 'Branson Harman',
#  'Renddal Foreste': 'Randall Forrester',
#  'Gnrzeo Hyuf': 'Gonzalo Huff',
#  'Madisen De': 'Madisen Decker',
#  'Semejq flumer': 'Semaj Plummer',
#  'Giovlehn Fugat': 'Giovanna Fugate',
#  'Kendarick xvin': 'Kendrick Gavin',
#  'Geynro Culveqr': 'Genaro Culver',
#  'Tee sNoeps': 'Thea Noyes',
#  'Kemron Bilingsfi': 'Kamron Billingsley',
#  'Tredt oHertan': 'Trent Hartmann',
#  'qKgaon Grifi': 'Keon Griffin',
#  'Nhastr Liht': 'Nestor Light',
#  'Gervns Kent': 'Gaven Kent',
#  'Javonte T': 'Javonte Trevino',
#  'Rocnen Baggt': 'Ronan Baggett',
#  'Kemrn Biullingli': 'Kamron Billingsley',
#  'Celo ormiegr': 'Carlo Cormier',
#  'Anslajy Wviles': 'Ansley Wilkes',
#  'Doriren Minca': 'Dorian Medina',
#  'onrued Msa': 'Conrad Mesa',
#  'kKeitlin Granham': 'Kaitlin Grantham',
#  'mKye os': 'Kya Doss',
#  'bPhonix cFonteine': 'Phoenix Fontaine',
#  'AndreemsrByers': 'Andreas Byers',
#  'Mariel S': 'Mariel Shearer',
#  'Julio C': 'Julio Clawson',
#  'erl Ckormiuer': 'Carlo Cormier',
#  'elgie Metzgejr': 'Halie Metzger',
#  'eyola Rncozn': 'Cayla Rincon',
#  'cayla rincon': 'Cayla Rincon',
#  'Kiney rSbtlings': 'Kinley Stallings',
#  'Coletmen lPeae': 'Coleman Peace',
#  'Hudsotn Guzden': 'Hudson Guzman',
#  'xRhy Wzyla': 'Rhys Wylie',
#  'Adren Glrf': 'Adrian Graff',
#  'Kehewn Steyin': 'Keshawn Stein',
#  'Jseyyn Cymr': 'Jaylynn Cyr',
#  'Holy troum': 'Holly Strom',
#  'Dinb Dunckorth': 'Dina Duckworth',
#  'Mximuss Fish': 'Maximus Fish',
#  'DeniagBvab': 'Dania Babb',
#  'iJevont Trevnqo': 'Javonte Trevino',
#  'Jeckeine pBrmicoe': 'Jackeline Briscoe',
#  'Gey Matson': 'Gary Matson',
#  'eClyxd Lindsi': 'Clyde Lindsay',
#  'unton Teylpor': 'Quinton Taylor',
#  'Peyton Mest': 'Peyton Mast',
#  'Mireanda avaze': 'Miranda Savage',
#  'EleeoAltamiralno': 'Elena Altamirano',
#  'Phoenivgx Fntene': 'Phoenix Fontaine',
#  'Teegakn Davidson': 'Teagan Davidson',
#  'Stuemrt Harman': 'Stuart Hartmann',
#  'C Travion': 'Travion Conley',
#  'jada valadez': 'Jada Valadez',
#  'Kelsie Se': 'Kelsie Segura',
#  'Betsy John B': 'Henry Johansen',
#  'L Irvin': 'Irvin Lira',
#  'Isabelle Ha': 'Isabelle Harman',
#  'daniela romo': 'Daniela Romo',
#  'Arman G': 'Arman Griswold',
#  'Kendrick G': 'Kendrick Gavin',
#  'Taron Sftroud': 'Theron Stroud',
#  'Susana Du': 'Susana Dunn',
#  'Adrian G': 'Adrian Graff',
#  'KzerulaFrak': 'Karla Frank',
#  'Gener Cuvemr': 'Genaro Culver',
#  'andreas byers': 'Andreas Byers',
#  'Ddnkise Werden': 'Denisse Warden',
#  'Gonvelo Huf': 'Gonzalo Huff',
#  'Mneximusnei': 'Maximus Fish',
#  'Leona C': 'Leona Cabral',
#  'Ger pMatsoon': 'Gary Matson',
#  'Genero Cuhver': 'Genaro Culver',
#  'Lyndssyt Jacobon': 'Lyndsay Jacobson',
#  'Abigeyqle Boen': 'Abigayle Bolen',
#  'Alizn Seels': 'Aylin Seals',
#  'nMonice Gerabosy': 'Monica Grabowski',
#  'kaycee carlin': 'Kaycee Carlin',
#  'kaylea hatton': 'Kaylea Hatton',
#  'DD': 'Jaquelin Duran',
#  'PA': 'Annette Ahmed',
#  'River F': 'River Feliciano',
#  'RG': 'Genevieve Ratliff',
#  'Abdlweh Hort': 'Abdullah Horst',
#  'Raefal Manwsfield': 'Rafael Mansfield',
#  'ArvaryAndrews': 'Avery Andrews',
#  'Jaime John G': 'Jaime Grimes',
#  'Yulie Dldnson': 'Yulisa Denson',
#  'griselda acuna': 'Griselda Acuna',
#  'MeximSjismonson': 'Maxim Simonson',
#  'GP': 'Genevieve Ratliff',
#  'Yulise Dtesqo': 'Yulisa Denson',
#  'Abigetyle Blen': 'Abigayle Bolen',
#  'lvin Veuneges': 'Alvin Venegas',
#  'fJmison Osorxio': 'Jamison Osorio',
#  'Diego S': 'Diego Shanks',
#  'Yousef L': 'Yousef Luttrell',
#  'JoehnyTson': 'Johnny Toney',
#  'BD': 'Jaquelin Duran',
#  'Kilejy Steings': 'Kinley Stallings',
#  'Koltben olend': 'Kolten Roland',
#  'Armevpn Grisold': 'Arman Griswold',
#  'Efrain Tr': 'Efrain Trujillo',
#  'Mitchell John R': 'Mitchell Ryan',
#  'pHeis arimsh': 'Harris Parish',
#  'SE': 'Daysha Sapp',
#  'KS': 'Keyara Camacho',
#  'Dametius Hutkchison': 'Demetrius Hutchison',
#  'TH': 'Branson Harman',
#  'Sebestcien Hwickmn': 'Sebastien Hickman',
#  'JS': 'Jaquelin Duran',
#  'Michel zRyn': 'Mitchell Ryan',
#  'S Daquan': 'Daquan Samuels',
#  'rerley Garibi': 'Harley Garibay',
#  'Roxanna T': 'Roxanna Toney',
#  'Dinx Duckwjorth': 'Dina Duckworth',
#  'Jece dDilon': 'Jacey Dillon',
#  'Ruh uCok': 'Ruth Cook',
#  'eeniele Wapldrop': 'Danielle Waldrop',
#  'Luiz McLeughlain': 'Luiz McLaughlin',
#  'Abigelle Sander': 'Abigayle Sander',
#  'M Chandler': 'Chandler McKinney',
#  'G Mira': 'Irvin Lira',
#  'MireGrefiewpld': 'Mira Greenfield',
#  'D Abrianna': 'Abrianna Delarosa',
#  'Maxim Si': 'Maxim Simonson',
#  'HF': 'Amalia Frost',
#  'pJeio Rei': 'Janie Reddy',
#  'brooke delgadillo': 'Brooke Delgadillo',
#  'Denisse John W': 'Denise Minor',
#  'Ashtyn qcnmen': 'Ashtyn Inman',
#  'C Kalee': 'Carlee Pearce',
#  'saul sweet': 'Saul Sweet',
#  'Chester C': 'Chester Chavez',
#  'Chrismea oWlbur': 'Charisma Wilbur',
#  'Barry La': 'Barry Laird',
#  'Deniele alroip': 'Danielle Waldrop',
#  'Abegal Margx': 'Abagail Marx',
#  'Chrplolte orenzo': 'Charlotte Lorenzo',
#  'Tobias John W': 'Tobias Wheeler',
#  'Aya John K': 'Amaris Jones',
#  'Hierlie Mtzer': 'Halie Metzger',
#  'TrecvionxConli': 'Travion Conley',
#  'Yesice rRcker': 'Yessica Rucker',
#  'Rowen Pquete': 'Rowan Paquette',
#  'Mekacla Brns': 'Makala Bruns',
#  'Geylislea Vilsenor': 'Galilea Villasenor',
#  'EleifneSel': 'Elaine Sell',
#  'C Keyara': 'Keyara Camacho',
#  'pGeret Sewasrt': 'Garrett Stewart',
#  'Luwhz McLeughlin': 'Luiz McLaughlin',
#  'K Jaycob': 'Lyndsay Jacobson',
#  'Cestirt Hulsi': 'Chastity Hulsey',
#  'GD': 'Jaquelin Duran',
#  'Deisy Burtoc': 'Daisy Burton',
#  'Kyre Opara': 'Kiya Ohara',
#  'eDelenie Gilbeyrton': 'Delanie Gilbertson',
#  'eevonte Trelvin': 'Javonte Trevino',
#  'Jeyna Rlmi': 'Elena Altamirano',
#  'Yujsaf Luttrel': 'Yousef Luttrell',
#  'Meriedn ears': 'Maren Sears',
#  'Netatjlia Hu': 'Natalia Huff',
#  'Susana H': 'Susana Healey',
#  'Adnslay Wilike': 'Ansley Wilkes',
#  'nnate Ahmepvd': 'Annette Ahmed',
#  'Htuson Gukzmen': 'Hudson Guzman',
#  'KP': 'Keyara Camacho',
#  'iAleeh Spanler': 'Aleah Spangler',
#  'Michetl Ryen': 'Mitchell Ryan',
#  'ES': 'Daysha Sapp',
#  'Jeycob Kaunman': 'Jaycob Kauffman',
#  'Monet W': 'Monet Wallace',
#  'Alnvrin Heden': 'Alvin Hayden',
#  'Meimust Fish': 'Maximus Fish',
#  'CB': 'Zachery Clancy',
#  'EB': 'Brianna Embry',
#  'dexter dunne': 'Dexter Dunne',
#  'MG': 'Dorothy Mayhew',
#  'S Theron': 'Theron Stroud',
#  'BdrenenKyec': 'Brennan Keck',
#  'Avjary Andrews': 'Avery Andrews',
#  'Josef F': 'Josef Finney',
#  'Julio vCleson': 'Julio Clawson',
#  'Holland John F': 'Holland Foy',
#  'ohnpeul Wing': 'Johnpaul Wing',
#  'Ashtyn John I': 'Ashtyn Inman',
#  'Aucuom Koh': 'Autum Kohn',
#  'Kathryn N': 'Kathryn Naranjo',
#  'Nestor John L': 'Nestor Light',
#  'Nesh Pasons': 'Nash Parsons',
#  'BrhzeBuford': 'Briza Buford',
#  'stuet Hanrtman': 'Stuart Hartmann',
#  'StgneReybjurn': 'Stone Rayburn',
#  'Ky Lintlajtohn': 'Koby Littlejohn',
#  'Coday Lyodn': 'Codey Lyon',
#  'Ansley W': 'Ansley Wilkes',
#  'aldo ragan': 'Aldo Ragan',
#  'Kethyn Nfarajo': 'Kathryn Naranjo',
#  'Jodi Toem': 'Jordi Tam',
#  'Dsigo Sheks': 'Diego Shanks',
#  'Trqet Hertman': 'Trent Hartmann',
#  'eriat Daii': 'Daria Daily',
#  'Kenene Stoe': 'Keenan Stone',
#  'hCerleeaqrce': 'Carlee Pearce',
#  'Herley arijbi': 'Harley Garibay',
#  'hesteru Ccevez': 'Chester Chavez',
#  'NH': 'Branson Harman',
#  'kJohnson Shuar': 'Johnson Schuler',
#  'MireyeGovifri': 'Mireya Godfrey',
#  'Autum Krhmn': 'Autum Kohn',
#  'Travion John C': 'Travion Conley',
#  'Yedsmin Sadlr': 'Yasmine Sadler',
#  'Deleniqe Gilbertsn': 'Delanie Gilbertson',
#  'Andree Byers': 'Andreas Byers',
#  'Serdenity Cetilo': 'Serenity Castillo',
#  'uercel Wener': 'Marcel Wenger',
#  'Payton A': 'Payton Atkinson',
#  'Derrion aripos': 'Darrion Barrios',
#  'Ampril Grmen': 'April Gorman',
#  'Gerald A': 'Gerald Arreola',
#  'Brennan K': 'Brennan Keck',
#  'Jeckeglie Biscoe': 'Jackeline Briscoe',
#  'Thnnaro Strod': 'Theron Stroud',
#  'Zoeia cDermot': 'Zoie McDermott',
#  'DB': 'Jaquelin Duran',
#  'Quntanyk Whitin': 'Quinten Whiting',
#  'Judithc Ck': 'Judith Crook',
#  'L Nancy': 'Zachery Clancy',
#  'milo greenfield': 'Milo Greenfield',
#  'Meximuds Ki': 'Maximus Fish',
#  'Daquan John S': 'Daquan Samuels',
#  'irey Bridges': 'Mira Bridges',
#  'Quinton John T': 'Quinton Taylor',
#  'Kendifck Gevi': 'Kendrick Gavin',
#  'colin hughes': 'Colin Hughes',
#  'Keea Praethor': 'Kaela Prather',
#  'JeseniePerafoles': 'Jessenia Perales',
#  'Axbigyle Sander': 'Abigayle Sander',
#  'Phoenix F': 'Phoenix Fontaine',
#  'Herman John T': 'Herman Turley',
#  'Ropxea oni': 'Roxanna Toney',
#  'ryann coker': 'Ryann Coker',
#  'dina duckworth': 'Dina Duckworth',
#  'Mckenzie John F': 'Mckenzie Finn',
#  'Nathanial Sa': 'Nathanial Sampson',
#  'K Aya': 'Keyara Camacho',
#  'MeximusdFish': 'Maximus Fish',
#  'sKirk evaria': 'Kirk Chavarria',
#  'Kubrt jWikns': 'Kurt Wilkins',
#  'Keeela Pather': 'Kaela Prather',
#  'Abiugeylae Boln': 'Abigayle Bolen',
#  'Jemiaon tOsorio': 'Jamison Osorio',
#  'Deshmaun Soear': 'Dashaun Sears',
#  'Kellie Eveer': 'Kallie Everett',
#  'erOrlendo Clemen': 'Orlando Clemens',
#  'HezetFoi': 'Mckenzie Finn',
#  'Abigayle Sa': 'Abigayle Sander',
#  'dYoslf Roli': 'Yosef Rowley',
#  'Jweime Grims': 'Jaime Grimes',
#  'Genaro Cu': 'Genaro Culver',
#  'Alivie iowel': 'Alivia Kidwell',
#  'JR': 'Jaquelin Duran',
#  'C Kaycee': 'Kaycee Carlin',
#  'MeldiaGarber': 'Malika Garber',
#  'Jeyna Rxowi': 'Jayna Rowley',
#  'Shanna John B': 'Shaniya Booth',
#  'Keseuy cGaril': 'Kasey Gabriel',
#  'betsy blake': 'Betsy Blake',
#  'Avery An': 'Avery Andrews',
#  'itwchell Rye': 'Mitchell Ryan',
#  'Dexter Du': 'Dexter Dunne',
#  'Chrlote orhenzo': 'Charlotte Lorenzo',
#  'Chester John C': 'Chester Chavez',
#  'Ctoda Lyon': 'Codey Lyon',
#  'Vnctor Dun': 'Victor Dunn',
#  'Kala John G': 'Karla Frank',
#  'Cerlote Lorernzo': 'Charlotte Lorenzo',
#  'Mira Gr': 'Mira Greenfield',
#  'Tege Noye': 'Thea Noyes',
#  'Borize Buorad': 'Briza Buford',
#  'Nesh Pasrongs': 'Nash Parsons',
#  'yndsey Schbuler': 'Lyndsay Schuler',
#  'Elliot H': 'Elliot Held',
#  'Celo hCojrmier': 'Carlo Cormier',
#  'ShwnlKi': 'Shawn Kay',
#  'xhMere Seas': 'Maren Sears',
#  'Galilea V': 'Galilea Villasenor',
#  'BhemryLaird': 'Barry Laird',
#  'Peyon Atkintson': 'Payton Atkinson',
#  'Jeycob Kaaufan': 'Jaycob Kauffman',
#  'AbigeyleSander': 'Abigayle Sander',
#  'Mira B': 'Mira Bridges',
#  'Debrke Clevenge': 'Debra Clevenger',
#  'DoriunMedina': 'Dorian Medina',
#  'Lveone Cabral': 'Leona Cabral',
#  'Deshaun Sdeas': 'Dashaun Sears',
#  'Jeycbu Kaukfman': 'Jaycob Kauffman',
#  'Javier Sh': 'Javier Shipley',
#  'lGndolyn Findli': 'Gwendolyn Findley',
#  'G Brady': 'Brady Grissom',
#  'Annatew Ahmed': 'Annette Ahmed',
#  'Gwendolyn John F': 'Gwendolyn Bain',
#  'Saul S': 'Saul Sweet',
#  'Malika G': 'Malika Garber',
#  'Tobies yvWhelr': 'Tobias Wheeler',
#  'hAleeh Crijde': 'Aleah Crider',
#  'Teagan John D': 'Teagan Davidson',
#  'JB': 'Jaquelin Duran',
#  'neshwn Balderas': 'Rashawn Balderas',
#  'nigel bunn': 'Nigel Bunn',
#  'Jemison cOsozio': 'Jamison Osorio',
#  'yasmine dunning': 'Yasmine Dunning',
#  'Hemen Turloi': 'Herman Turley',
#  'Kinley St': 'Kinley Stallings',
#  'Avary sndrews': 'Avery Andrews',
#  'SeshaSwuat': 'Sasha Sweat',
#  'evonte Trelvnino': 'Javonte Trevino',
#  'MeximmswKei': 'Maximus Kelly',
#  'Keetarina Hershbeger': 'Katerina Hershberger',
#  'Tqreth Hetman': 'Trent Hartmann',
#  'H Adeline': 'Adeline Henry',
#  'Boooke Declgedilo': 'Brooke Delgadillo',
#  'Stuert Hartadbn': 'Stuart Hartmann',
#  'Ceelan Infate': 'Caelan Infante',
#  'eycotb aufman': 'Jaycob Kauffman',
#  'Abigeyle oleen': 'Abigayle Bolen',
#  'L Crystal': 'Crystal Leavitt',
#  'RehelexLamb': 'Rachelle Lamb',
#  'Perry erymben': 'Perry Perryman',
#  'Syde rMeefs': 'Sydnee Mears',
#  'Marcel John W': 'Marcello Weber',
#  'leni Arendda': 'Eleni Aranda',
#  'Mekalm Bruns': 'Makala Bruns',
#  'Rehul era': 'Rahul Vera',
#  'nallely covey': 'Nallely Covey',
#  'Monica John G': 'Monica Grabowski',
#  'Nelely lovi': 'Nallely Covey',
#  'JhnpeulWiangg': 'Johnpaul Wing',
#  'Johnnie John M': 'Johnnie Moody',
#  'nathanial sampson': 'Nathanial Sampson',
#  'L Jonathon': 'Johnathon Leger',
#  'Cendy Duena': 'Candy Duenas',
#  'Gwendoxlyn enin': 'Gwendolyn Findley',
#  'Johnfon Schulaxr': 'Johnson Schuler',
#  'daonr Grifi': 'Keon Griffin',
#  'Jordi T': 'Jordi Tam',
#  'james patrick': 'James Patrick',
#  'DW': 'Jaquelin Duran',
#  'Rejchele Lab': 'Rachelle Lamb',
#  'Dametrius fHuhison': 'Demetrius Hutchison',
#  'Hrmony McDhermot': 'Harmony McDermott',
#  'CeyilySeward': 'Cailyn Seward',
#  'Makala B': 'Makala Bruns',
#  'Tsevion Colpi': 'Travion Conley',
#  'Dine Duckwrtph': 'Dina Duckworth',
#  'Elen Arenda': 'Eleni Aranda',
#  'LyndseeySchule': 'Lyndsay Schuler',
#  'M Halie': 'Susana Healey',
#  'Nklely Cvli': 'Nallely Covey',
#  'Allen M': 'Allen McPherson',
#  'Lue aanders': 'Luca Sanders',
#  'Keyara Ca': 'Keyara Camacho',
#  'Jecklyn Saenz': 'Jacklyn Saenz',
#  'Cemill Crhan': 'Camille Curran',
#  'Efren Trudilo': 'Efrain Trujillo',
#  'Necy Laeb': 'Nancy Lamb',
#  'W Danielle': 'Danielle Waldrop',
#  'tAleehCride': 'Aleah Crider',
#  'Byrooke pelgedilo': 'Brooke Delgadillo',
#  'Te Klinme': 'Tai Kline',
#  'Shaldon nErn': 'Sheldon Ernst',
#  'Jelin Mlyigan': 'Jalin Milligan',
#  'Quntan mWhiting': 'Quinten Whiting',
#  'Trent John H': 'Henry Johansen',
#  'Jean H': 'Jean Hickey',
#  'AlizaydDod': 'Alize Dodd',
#  'Abegaibl arx': 'Abagail Marx',
#  'Jevonth Trekvino': 'Javonte Trevino',
#  'MS': 'Dorothy Mayhew',
#  'perony McDermot': 'Harmony McDermott',
#  'Tine Rickp': 'Tina Ricker',
#  'GedrretSewart': 'Garrett Stewart',
#  'BleyneiPolocek': 'Blayne Pollock',
#  'KurtzWilkins': 'Kurt Wilkins',
#  'efaelMansfienld': 'Rafael Mansfield',
#  'jCdherisma Wilbr': 'Charisma Wilbur',
#  'Abigeye Srahnde': 'Abigayle Sander',
#  'Chastity Ly': 'Chastity Lyle',
#  'Brize Busfjrd': 'Briza Buford',
#  'IP': 'Irvin Lira',
#  'Bieson Harman': 'Branson Harman',
#  'Charlotte Lo': 'Charlotte Lorenzo',
#  'Cpilyng Sewrd': 'Cailyn Seward',
#  'Hezelx i': 'Hazel Fry',
#  'AnthonzyLleas': 'Anthony Llamas',
#  'Jkeyna Rwli': 'Jayna Rowley',
#  'Debe Clevpenger': 'Debra Clevenger',
#  'Danielle John W': 'Daniela Romo',
#  'Mepiel Shearer': 'Mariel Shearer',
#  'Mereal Sharer': 'Mariel Shearer',
#  'Randall Fo': 'Randall Forrester',
#  'Tharon eStwrod': 'Theron Stroud',
#  'Mire Bxidgs': 'Mira Bridges',
#  'Monica Gr': 'Monica Grabowski',
#  'Jordin odrigudaws': 'Jordin Rodrigues',
#  'Coluin Hugqhs': 'Colin Hughes',
#  'ynsly Wilkes': 'Ansley Wilkes',
#  'Gwerndoilyn Bin': 'Gwendolyn Bain',
#  'Mexim fkimonon': 'Maxim Simonson',
#  'autum kohn': 'Autum Kohn',
#  'Rhys Wyli': 'Rhys Wylie',
#  'Debr Cevmenger': 'Debra Clevenger',
#  'FG': 'Finn Mullins',
#  'Jenie Rei': 'Janie Reddy',
#  'Dellas Ba': 'Dallas Ball',
#  'Heel kFi': 'Jocelyn Fitzsimmons',
#  'odaymLyon': 'Codey Lyon',
#  'cAshtynInmen': 'Ashtyn Inman',
#  'Yasmine John S': 'Yasmine Dunning',
#  'Pfeytb Atkinson': 'Payton Atkinson',
#  'Nestor L': 'Nestor Light',
#  'Jownpeul Wing': 'Johnpaul Wing',
#  'Die Duckqworath': 'Dina Duckworth',
#  'Sheilniya Bh': 'Shaniya Booth',
#  'KemronBiulingsl': 'Kamron Billingsley',
#  'Kiya O': 'Kiya Ohara',
#  'Keshawn John S': 'Keshawn Stein',
#  'Ashanti Ko': 'Ashanti Koenig',
#  'Mitchel Crcorern': 'Mitchel Corcoran',
#  'CodayLyoqn': 'Codey Lyon',
#  'Alivia K': 'Alivia Kidwell',
#  'Jevonte rqevino': 'Javonte Trevino',
#  'Roen Bghget': 'Ronan Baggett',
#  'CW': 'Zachery Clancy',
#  'Blyene Mckentzie': 'Blaine Mckenzie',
#  'Branson H': 'Branson Harman',
#  'Brookwe Deledilo': 'Brooke Delgadillo',
#  'April Go': 'April Gorman',
#  'keyana grubbs': 'Keyana Grubbs',
#  'AB': 'Annette Ahmed',
#  'AH': 'Annette Ahmed',
#  'kYousafLuttrel': 'Yousef Luttrell',
#  'easeFryanz': 'Jase Franz',
#  'B Kamron': 'Kamron Billingsley',
#  'Amewn Griswold': 'Arman Griswold',
#  'Aemliese Gies': 'Annaliese Giles',
#  'JeyvonKirjk': 'Jayvon Kirk',
#  'YulriqeDenson': 'Yulisa Denson',
#  'Helen Metzer': 'Halie Metzger',
#  'Mrena Sapavage': 'Miranda Savage',
#  'Holyb Str': 'Holly Strom',
#  'KneitlynSoelo': 'Kaitlynn Sotelo',
#  'Neah Pasohns': 'Nash Parsons',
#  'Jayna Ro': 'Jayna Rowley',
#  'Adullfeh Ri': 'Abdullah Reddy',
#  'AS': 'Annette Ahmed',
#  'Dequlan Samuls': 'Daquan Samuels',
#  'Cdy eGeri': 'Brady Grissom',
#  'Mexim Sionskon': 'Maxim Simonson',
#  'Halie Me': 'Halie Metzger',
#  'olsby Smurm': 'Kolby Sturm',
#  'Hudo Gquzmen': 'Hudson Guzman',
#  'Ceelajn Ifdante': 'Caelan Infante',
#  'Adrien Gzrf': 'Adrian Graff',
#  'Kela Navaretee': 'Kaylea Navarrete',
#  'Ronan John B': 'Roxanna Toney',
#  'Aprrl Gomen': 'April Gorman',
#  'Rhyts Wyia': 'Rhys Wylie',
#  'Keyana Gr': 'Keyana Grubbs',
#  'Desy wBurtn': 'Daisy Burton',
#  'Dequba amuelgs': 'Daquan Samuels',
#  'KG': 'Keyara Camacho',
#  'brady grissom': 'Brady Grissom',
#  'Munet Wlelac': 'Monet Wallace',
#  'Aalyr Andrews': 'Avery Andrews',
#  'Nehaly Lavoie': 'Nathaly Lavoie',
#  'M Johnnie': 'Johnnie Moody',
#  'crystal leavitt': 'Crystal Leavitt',
#  'GievGri': 'Jaime Grimes',
#  'Jada Va': 'Jada Valadez',
#  'Merieaa Sherer': 'Mariel Shearer',
#  'Jedla Valade': 'Jada Valadez',
#  'Ahleh Spanglver': 'Aleah Spangler',
#  'harris parish': 'Harris Parish',
#  'Eleivne Sel': 'Elaine Sell',
#  'Keitli mGranbtam': 'Kaitlin Grantham',
#  'Derio Wxhte': 'Dario White',
#  'Aary Anrevws': 'Avery Andrews',
#  'Adiuleh Horst': 'Abdullah Horst',
#  'Rive Felsicieno': 'River Feliciano',
#  'ejmfe Grimes': 'Jaime Grimes',
#  'MB': 'Dorothy Mayhew',
#  'Demetrius John H': 'Demetrius Hutchison',
#  'Milo Grafaild': 'Milo Greenfield',
#  'GieqGri': 'Jaime Grimes',
#  'Besy Blzke': 'Betsy Blake',
#  'Kr vWilkins': 'Kurt Wilkins',
#  'Cayla John R': 'Cayla Rincon',
#  'Keeyl Gabriel': 'Kasey Gabriel',
#  'Jemckelizne Brscoe': 'Jackeline Briscoe',
#  'RhecheleLamb': 'Rachelle Lamb',
#  'Arien Grazf': 'Adrian Graff',
#  'Arman John G': 'Autum Kohn',
#  'MeximsfFivsh': 'Maximus Fish',
#  'MivtchelCorcoren': 'Mitchel Corcoran',
#  'Peyton Atkinso': 'Payton Atkinson',
#  'Luiz M': 'Luiz McLaughlin',
#  'ZoiabMcDermot': 'Zoie McDermott',
#  'PqhoenipxFontine': 'Phoenix Fontaine',
#  'Eleine tSel': 'Elaine Sell',
#  'W Denisse': 'Denisse Warden',
#  'Susana John D': 'Susana Dunn',
#  'Stkuerct Hatman': 'Stuart Hartmann',
#  'Jemzes Paotrc': 'James Patrick',
#  'Nigdln Bun': 'Nigel Bunn',
#  'Caelan I': 'Caelan Infante',
#  'Krt cMunuie': 'Kurt Munguia',
#  'MireBrvides': 'Mira Bridges',
#  'Alivie Kidwel': 'Alivia Kidwell',
#  'Fidelqem': 'Gwendolyn Findley',
#  'Candace Ba': 'Candace Barkley',
#  'Hbleren Tuli': 'Herman Turley',
#  'qDefnis Seure': 'Denise Segura',
#  'Ashanti K': 'Ashanti Koenig',
#  'Jaycob Ka': 'Jaycob Kauffman',
#  'Shzeniy Both': 'Shaniya Booth',
#  'Peytbo Mest': 'Peyton Mast',
#  'Lyjndsey Jaaobon': 'Lyndsay Jacobson',
#  'Johnnie Mo': 'Johnnie Moody',
#  'garrett stewart': 'Garrett Stewart',
#  'exkimus Ki': 'Maximus Fish',
#  'Kolbly Sjurm': 'Kolby Sturm',
#  'TN': 'Braden Thorne',
#  'Keela Pratpker': 'Kaela Prather',
#  'Glenz Drefr': 'Glen Draper',
#  'Gary Pa': 'Gary Paxton',
#  'Dlla Bpal': 'Dallas Ball',
#  'Fnn Goowin': 'Finn Goodwin',
#  'Adeline He': 'Adeline Henry',
#  'Avary ndrcews': 'Avery Andrews',
#  'IB': 'Irvin Lira',
#  'Kthrnyn Nrandjo': 'Kathryn Naranjo',
#  'Rhienonw Swyif': 'Rhiannon Swift',
#  'nestor light': 'Nestor Light',
#  'Jessenia P': 'Jessenia Perales',
#  'Adreezs yers': 'Andreas Byers',
#  'dKerla Fwank': 'Karla Frank',
#  'Denise Seyure': 'Denise Segura',
#  'Kshewcn Stei': 'Keshawn Stein',
#  'Sebastien Hi': 'Sebastien Hickman',
#  'GG': 'Genevieve Ratliff',
#  'Diego John S': 'Diego Shanks',
#  'Aldo Ra': 'Aldo Ragan',
#  'gJea Valade': 'Jada Valadez',
#  'Guillermo Ha': 'Guillermo Hackney',
#  'enepo Culver': 'Genaro Culver',
#  'hEvleine el': 'Elaine Sell',
#  'Jeyna whli': 'Jayna Rowley',
#  'eshun jSears': 'Dashaun Sears',
#  'Y Stevie': 'Stevie Young',
#  'Jeceys Dlon': 'Jacey Dillon',
#  'Conrad John M': 'Conrad Mesa',
#  'S Javier': 'Javier Breaux',
#  'YosftRowli': 'Yosef Rowley',
#  'Kirk Cehevaia': 'Kirk Chavarria',
#  'Yurlie Densn': 'Yulisa Denson',
#  'Arali kSe': 'Areli Seeley',
#  'Sana John F': 'Roxanna Toney',
#  'Alvin H': 'Alvin Hayden',
#  'Kirek Chtvaria': 'Kirk Chavarria',
#  'Kelsie Segurde': 'Kelsie Segura',
#  'Annaliese Gi': 'Annaliese Giles',
#  'Brdy Gdriso': 'Brady Grissom',
#  'Annezbelle Mal': 'Annabelle Malloy',
#  'shttyn Inmen': 'Ashtyn Inman',
#  'Jeev Hecki': 'Jean Hickey',
#  'Jxecklyn San': 'Jacklyn Saenz',
#  'Emerson wSemjul': 'Emerson Samuel',
#  'Hudson Gu': 'Hudson Guzman',
#  'harcon Stoud': 'Theron Stroud',
#  'yKurt Mmungue': 'Kurt Munguia',
#  'Luce Savners': 'Luca Sanders',
#  'johnnie moody': 'Johnnie Moody',
#  'fKeterina Hrshberger': 'Katerina Hershberger',
#  'Kurt Mongumie': 'Kurt Munguia',
#  'Metias Cordermo': 'Matthias Cordero',
#  'Stephon Burdne': 'Stephon Burnett',
#  'bKeloea Navarete': 'Kaylea Navarrete',
#  'D Candy': 'Zachery Clancy',
#  'Monce rajbowsy': 'Monica Grabowski',
#  'Zoiat Mgcermo': 'Zoie McDermott',
#  'Orlendo Cemens': 'Orlando Clemens',
#  'zFde Serm': 'Fidel Sam',
#  'Nash P': 'Nash Parsons',
#  'Denisse W': 'Denisse Warden',
#  'Keliyvah nHidalo': 'Kaliyah Hidalgo',
#  'EliseNegrzete': 'Elisa Negrete',
#  'rAprl gGormn': 'April Gorman',
#  'Ashanti John K': 'Ashanti Koenig',
#  'Abigayle S': 'Abigayle Sander',
#  'Toaybies Weler': 'Tobias Wheeler',
#  'Johnpaul Wi': 'Johnpaul Wing',
#  'Stone Reyurqn': 'Stone Rayburn',
#  'QW': 'Tobias Wheeler',
#  'Abdullah John R': 'Abdullah Horst',
#  'Yisronal Stor': 'Yisroel Storm',
#  'Prjry Prymen': 'Perry Perryman',
#  'JeylxynCyr': 'Jaylynn Cyr',
#  'Mitcwzhel Ryn': 'Mitchell Ryan',
#  'keith dempsey': 'Keith Dempsey',
#  'Brooke Delgeelbo': 'Brooke Delgadillo',
#  'Iusebele Hroma': 'Isabelle Harman',
#  'Anthny Ljlemas': 'Anthony Llamas',
#  'Bred Grislom': 'Brady Grissom',
#  'Ghie Gri': 'Jaime Grimes',
#  'Gretchenh Cwson': 'Gretchen Clawson',
#  'Zyia MchDermot': 'Zoie McDermott',
#  'Keiftly Sotelo': 'Kaitlynn Sotelo',
#  'IH': 'Branson Harman',
#  'Herleby Grii': 'Harley Garibay',
#  'Javier S': 'Javier Shipley',
#  'EleneAleaumirano': 'Elena Altamirano',
#  'HS': 'Branson Harman',
#  'Autum John K': 'Autum Kohn',
#  'travion conley': 'Travion Conley',
#  'Kespmro Bilingsli': 'Kamron Billingsley',
#  'Jisme Grims': 'Jaime Grimes',
#  'Hli Metzgaer': 'Halie Metzger',
#  'Anneelznle Mali': 'Annabelle Malloy',
#  'Peyton As': 'Peyton Ashford',
#  'Mereno Seas': 'Maren Sears',
#  'tChestrr Chvez': 'Chester Chavez',
#  'JP': 'Jaquelin Duran',
#  'Gven Knet': 'Gaven Kent',
#  'Susen Hemali': 'Susana Healey',
#  'Kewylea Nvaree': 'Kaylea Navarrete',
#  'Abcigeyle Salder': 'Abigayle Sander',
#  'Cy yGgeri': 'Litzy Moyer',
#  'Ruth Co': 'Ruth Cook',
#  'KurtgbWilkins': 'Kurt Wilkins',
#  'Chesntity Lyle': 'Chastity Lyle',
#  'Isebel Harmnan': 'Isabelle Harman',
#  'Leonj Cabral': 'Leona Cabral',
#  'Natalia John H': 'Natalia Huff',
#  'Efrain John T': 'Efrain Trujillo',
#  'Mirecy Godfi': 'Mireya Godfrey',
#  'Cuelen Clabrmese': 'Cullen Calabrese',
#  'Gery Paxtn': 'Gary Paxton',
#  'P Isabell': 'Isabelle Harman',
#  'Finn Godwivn': 'Finn Goodwin',
#  'efrain trujillo': 'Efrain Trujillo',
#  'Kenpn Stonz': 'Keenan Stone',
#  'Cody Me': 'Cody Medina',
#  'Eleni A': 'Eleni Aranda',
#  'buitonr Teylor': 'Quinton Taylor',
#  'fJobnpul Wing': 'Johnpaul Wing',
#  'B Nigel': 'Nigel Bunn',
#  'Gary John M': 'Henry Johansen',
#  'Peyton M': 'Peyton Mast',
#  'Mirenda Savte': 'Miranda Savage',
#  'Cldah Buolin': 'Clyde Bolin',
#  'Shaniya B': 'Shaniya Booth',
#  'Tobias Wh': 'Tobias Wheeler',
#  'Yisral Storltm': 'Yisroel Storm',
#  'Apdlm Gormen': 'April Gorman',
#  'jYesmiane Dning': 'Yasmine Dunning',
#  'Knybe Ptlrick': 'Kenya Patrick',
#  'Cerzle Pere': 'Carlee Pearce',
#  'Sheldon Er': 'Sheldon Ernst',
#  'Annalise John D': 'Annalise Dietz',
#  'iune Dckworth': 'Dina Duckworth',
#  'Mire Grnifield': 'Mira Greenfield',
#  'Geoffrey R': 'Geoffrey Riddle',
#  'Gry iuPaxton': 'Gary Paxton',
#  'mitchel corcoran': 'Mitchel Corcoran',
#  'Yesaminpe Sdler': 'Yasmine Sadler',
#  'FM': 'Dorothy Mayhew',
#  'daisha yoon': 'Daisha Yoon',
#  'enniele Waldrop': 'Danielle Waldrop',
#  'Stapho mrot': 'Stephon Smoot',
#  'Judith C': 'Judith Crook',
#  'Candy Du': 'Candy Duenas',
#  'Aldo Realn': 'Aldo Ragan',
#  'Jordin Roriouas': 'Jordin Rodrigues',
#  'arman griswold': 'Arman Griswold',
#  'NeshzParsons': 'Nash Parsons',
#  'Chrlogcte Lorenz': 'Charlotte Lorenzo',
#  'Ger atmxton': 'Gary Paxton',
#  'Devnise egure': 'Denise Segura',
#  'Daniela John R': 'Daniela Romo',
#  'Gafreoy Ridle': 'Geoffrey Riddle',
#  'uwNeely ovi': 'Nallely Covey',
#  'Leuhl Rt': 'Leah Root',
#  'Kirk C': 'Kirk Chavarria',
#  'Jeynva Rwl': 'Jayna Rowley',
#  'Caelan In': 'Caelan Infante',
#  'Kxesey Gabrel': 'Kasey Gabriel',
#  'darien martens': 'Darien Martens',
#  'Shena nraqnch': 'Shanna Branch',
#  'Gaoiffee Ridle': 'Geoffrey Riddle',
#  'Mitchiel orcdren': 'Mitchel Corcoran',
#  'Dina D': 'Dina Duckworth',
#  'Kolten R': 'Kolten Roland',
#  'F Mckenzie': 'Blaine Mckenzie',
#  'Roxnax Mcair': 'Roxanna McNair',
#  'Mckenzie F': 'Mckenzie Finn',
#  'Gonzalo Hu': 'Gonzalo Huff',
#  'Aleh lSpanger': 'Aleah Spangler',
#  'D Teagan': 'Teagan Davidson',
#  'Daisyv Burton': 'Daisy Burton',
#  'Tyrique C': 'Tyrique Crane',
#  'Herley Gxarbi': 'Harley Garibay',
#  'JohnlpeulWing': 'Johnpaul Wing',
#  'Aneliese Gieds': 'Annaliese Giles',
#  'olnten olend': 'Kolten Roland',
#  'Isebele armahn': 'Isabelle Harman',
#  'Zwecarhy Naylor': 'Zackary Naylor',
#  'Adieu Graf': 'Adrian Graff',
#  'Kinley John S': 'Kinley Stallings',
#  'Ashtyn In': 'Ashtyn Inman',
#  'Pjayton eAshord': 'Peyton Ashford',
#  'D Brooke': 'Brooke Delgadillo',
#  'RuiverFlicieno': 'River Feliciano',
#  'eyera Camkaco': 'Keyara Camacho',
#  'Kaela P': 'Kaela Prather',
#  'oSnebesten Hickan': 'Sebastien Hickman',
#  'M Annabelle': 'Annabelle Malloy',
#  'Evelin Brepdli': 'Evelin Bradley',
#  'Gaeneryo lver': 'Genaro Culver',
#  'eeven Kent': 'Gaven Kent',
#  'Johnidaa oi': 'Johnnie Moody',
#  'Ceelan Inrfanht': 'Caelan Infante',
#  'A Eleni': 'Eleni Aranda',
#  'Tharon Stroud': 'Theron Stroud',
#  'CD': 'Zachery Clancy',
#  'lipne Sel': 'Elaine Sell',
#  'Tinesicker': 'Tina Ricker',
#  'bMxim Simonson': 'Maxim Simonson',
#  'Tyrique Cr': 'Tyrique Crane',
#  'xIsbele Hxarman': 'Isabelle Harman',
#  'Victor John D': 'Victor Dunn',
#  'Kinxley Stelngs': 'Kinley Stallings',
#  'javier shipley': 'Javier Shipley',
#  'Ryen Coke': 'Kaycee Coker',
#  'Yosaf fsRowl': 'Yosef Rowley',
#  'Keye Hation': 'Kaylea Hatton',
#  'Gonznlo ouf': 'Gonzalo Huff',
#  'Stmer Hnamond': 'Starr Hammond',
#  'JulioClewson': 'Julio Clawson',
#  'dSsena Hfali': 'Susana Healey',
#  'ermen Turli': 'Herman Turley',
#  'D Keith': 'Keith Dempsey',
#  'Aegail Marx': 'Abagail Marx',
#  'Leone habral': 'Leona Cabral',
#  'eximusjKei': 'Maximus Kelly',
#  'Abdullah H': 'Abdullah Horst',
#  'O Jamison': 'Jamison Osorio',
#  'Kaitlin G': 'Kaitlin Grantham',
#  'Griselda Ac': 'Griselda Acuna',
#  ...}

# %%
df_part['Name'] = df_part['Name'].replace(name_part_dict)

# %%
len(name_part_dict)
# Out:
# 3903

# %%
df_part['Name'].nunique()
# Out:
# 542

# %%
df_part['Name'].isnull().sum()
# Out:
# 0

# %%
df_part['Name']
# Out:
# 0          Jayna Rowley
# 1          Candy Duenas
# 2        Jaquelin Duran
# 3       Kaliyah Hidalgo
# 4           Elaine Sell
#              ...
# 4764    Candace Barkley
# 4765    Debra Clevenger
# 4766      Theron Stroud
# 4767     Branson Harman
# 4768      Jadon Vandyke
# Name: Name, Length: 4769, dtype: object

# %%
df4_names = list(df_club['Name'].unique())
names = []
for x in df4_names:
    match = match_names(x, df1_names, 45)
    if match[1] >= 45:
        name = ((  str(x), str(match[0])  ))
        names.append(name)
name_club_dict = dict(names)

# %%
name_club_dict
# Out:
# {'Darien Ma': 'Darien Martens',
#  'Sege Schrock': 'Sage Schrock',
#  'Alison bci': 'Alison Mcvey',
#  'kiara jauregui': 'Kiara Jauregui',
#  'Tete Buim': 'Tate Blum',
#  'Loufis emuls': 'Louis Samuels',
#  'MercezloWeber': 'Marcello Weber',
#  'hJeine uMcCormack': 'Janine McCormack',
#  'Quinton Ta': 'Quinton Taylor',
#  'Jjnine McCormack': 'Janine McCormack',
#  'Everardo John C': 'Everardo Cronin',
#  'Were Scholfield': 'Warren Schofield',
#  'Ezpre Lod': 'Ezra Lord',
#  'Aya K': 'Aya Kennedy',
#  'Alannah C': 'Alannah Chisholm',
#  'Gremysan eim': 'Grayson Heim',
#  'NG': 'Adrian Graff',
#  'Judithee Howend': 'Judith Howland',
#  'Milo Grafeild': 'Milo Greenfield',
#  'A Elena': 'Abigayle Bolen',
#  'HeylieGajri': 'Haylie Garay',
#  'Sen Fairbaenks': 'Sana Fairbanks',
#  'oEvelin rerdli': 'Evelin Bradley',
#  'denise minor': 'Denise Minor',
#  'Sentagok Nadeau': 'Santiago Nadeau',
#  'Grady S': 'Grady Sample',
#  'CxhhelseyDeen': 'Chelsey Dean',
#  'JM': 'Jaquelin Duran',
#  'eriuws Albers': 'Darrius Albers',
#  'Annabelle Ma': 'Annabelle Malloy',
#  'Ntaliyja Garvin': 'Natalya Garvin',
#  'Alize John D': 'Alize Dodd',
#  'Brannen Elizn': 'Brennen Ellison',
#  'Daeegelox Neuman': 'Deangelo Neuman',
#  'Luci Coi': 'Lucia Cody',
#  'gKeraJauregy': 'Kiara Jauregui',
#  'Lexis Wh': 'Lexis Whitley',
#  'Kzla renfield': 'Kala Greenfield',
#  'Reymundo zapata': 'Raymundo Zapata',
#  'Gelvil Vilasenhor': 'Galilea Villasenor',
#  'Gustavo Mu': 'Gustavo Mull',
#  'Linda John B': 'Lyndsay Jacobson',
#  'krali Seli': 'Areli Seeley',
#  'Judit Howlernd': 'Judith Howland',
#  'eredk Gui': 'Jared Gulley',
#  'gRdy Bredli': 'Rudy Bradley',
#  'D Cathryn': 'Cathryn Duarte',
#  'Litzy Moqr': 'Litzy Moyer',
#  'Eveli Bedvli': 'Evelin Bradley',
#  'LaxxisWhital': 'Lexis Whitley',
#  'Meljorie Sanz': 'Mallorie Saenz',
#  'Aleedreba Starnes': 'Alexandrea Starnes',
#  'RD': 'Jaquelin Duran',
#  'G Sean': 'Abigayle Sander',
#  'natalya garvin': 'Natalya Garvin',
#  'GedySamhple': 'Grady Sample',
#  'D Dexter': 'Dexter Dunne',
#  'Eivelin Bredl': 'Evelin Bradley',
#  'Jocelyn F': 'Jocelyn Fitzsimmons',
#  'Krla tParis': 'Karla Parris',
#  'shea jenkins': 'Shea Jenkins',
#  'Aomqeiya olano': 'Amaiya Solano',
#  'Thee McCloyd': 'Thea McCloud',
#  'Brgittozn Gilaspi': 'Britton Gillespie',
#  'Lide Brzenan': 'Linda Brennan',
#  'Alenah ahishnolm': 'Alannah Chisholm',
#  'CH': 'Zachery Clancy',
#  'Aloiae Ervn': 'Alina Ervin',
#  'Dorisu rebo': 'Doris Prado',
#  'Johson Smchlar': 'Johnson Schuler',
#  'Kzeyleighoennig': 'Kayleigh Koenig',
#  'Lorena L': 'Lorena Lamar',
#  'tKierstn ilerd': 'Kierstin Millard',
#  'Jemeh Patick': 'James Patrick',
#  'GH': 'Branson Harman',
#  'Stephon Bu': 'Stephon Burnett',
#  'L Misty': 'Misty Lavoie',
#  'Gelilea Vilasquenr': 'Galilea Villasenor',
#  'Joequn Crisbt': 'Joaquin Crist',
#  'Killien Ratllif': 'Killian Ratliff',
#  'Alexendea pStrnes': 'Alexandrea Starnes',
#  'JeredGulai': 'Jared Gulley',
#  'roxanna mcnair': 'Roxanna McNair',
#  'fLeltrel Esli': 'Latrell Easley',
#  'ore Srnyder': 'Nora Snyder',
#  'Shnaz Branch': 'Shanna Branch',
#  'RudyBrejdli': 'Rudy Bradley',
#  'pLcrie Coi': 'Lucia Cody',
#  'A Griselda': 'Griselda Acuna',
#  'Jenine McCuormwk': 'Janine McCormack',
#  'Delenise Gilbezrtsn': 'Delanie Gilbertson',
#  'zSetiago Ndeau': 'Santiago Nadeau',
#  'Luwzceno Sims': 'Luciano Sims',
#  'Yisnral Sik': 'Yisroel Sisk',
#  'iDeyna Sele': 'Dayna Steele',
#  'Ttum Hxeing': 'Tatum Henning',
#  'Serenity John C': 'Serenity Ngo',
#  'Dereio Whte': 'Dario White',
#  'Aianslay Cinton': 'Ainsley Clinton',
#  'agidi Whitmore': 'Heidi Whitmore',
#  'vAlexenrea Strnes': 'Alexandrea Starnes',
#  'A Ciera': 'Ciera Almanza',
#  'FernendSegovwia': 'Fernando Segovia',
#  'jazmyn schmid': 'Jazmyn Schmid',
#  'Evelign Brdi': 'Evelin Bradley',
#  'Memrwc Rand': 'Marco Rand',
#  'AC': 'Annette Ahmed',
#  'Furnendo Segovia': 'Fernando Segovia',
#  'R Janie': 'Alexander Jaimes',
#  'Mckenzie H': 'Mckenzie Hitchcock',
#  'Crystal Le': 'Crystal Leavitt',
#  'keri carrier': 'Keri Carrier',
#  'Mzlorie Saenz': 'Mallorie Saenz',
#  'Bteby Haato': 'Baby Heaton',
#  'ChriestiongCohan': 'Christion Cohen',
#  'Jhny Tovnfi': 'Johnny Toney',
#  'LW': 'Irvin Lira',
#  'JedonVandykce': 'Jadon Vandyke',
#  'Wlsonu Sloocum': 'Wilson Slocum',
#  'KC': 'Zachery Clancy',
#  'Rylia omez': 'Rylie Gomez',
#  'Rowan Pa': 'Rowan Paquette',
#  'W Kalista': 'Kalista Whiteside',
#  'Grayson He': 'Grayson Heim',
#  'ylicn Sels': 'Aylin Seals',
#  'kalen logan': 'Kalen Logan',
#  'Yisrol Sihsk': 'Yisroel Sisk',
#  'GM': 'Dorothy Mayhew',
#  'Se Jenakins': 'Shea Jenkins',
#  'Joeqin aCrzist': 'Joaquin Crist',
#  'Wisn Slogxcum': 'Wilson Slocum',
#  'Chanel John P': 'Chanel Pickett',
#  'C Jedidiah': 'Jedidiah Clarkson',
#  'eyvvon irpk': 'Jayvon Kirk',
#  'Lawis Bredlove': 'Lewis Breedlove',
#  'iecstin Romeno': 'Kierstin Romano',
#  'Joequin sCrisl': 'Joaquin Crist',
#  'C Everardo': 'Everardo Cronin',
#  'Kiestin Romepno': 'Kierstin Romano',
#  'Jdizt Hofwlend': 'Judith Howland',
#  'B Joselyn': 'Joselyn Barrow',
#  'Ea hdRing': 'Eden Ring',
#  'Thoaoore Schmdt': 'Theodore Schmidt',
#  'Mireya Go': 'Mireya Godfrey',
#  'ielea Casilas': 'Kalee Casillas',
#  'Sege chroctk': 'Sage Schrock',
#  'mJerrett sui': 'Jarrett Murry',
#  'Nancy John L': 'Nancy Lamb',
#  'M Sydnee': 'Sydnee Mears',
#  'Aindrawr Kee': 'Andrew Keefe',
#  'Kebtrine Lene': 'Kathrine Leone',
#  'kEzre Lord': 'Ezra Lord',
#  'kAmber onse': 'Amber Costa',
#  'IL': 'Irvin Lira',
#  'Monet Wa': 'Monet Wallace',
#  'TeoshaSmali': 'Tasha Smalley',
#  'Kelee Cxlsilas': 'Kalee Casillas',
#  'Tatum John H': 'Autum Kohn',
#  'Luciano Si': 'Luciano Sims',
#  'Lukas John M': 'Lukas McGee',
#  'tatum henning': 'Tatum Henning',
#  'Jacey D': 'Jacey Dillon',
#  'Katelynn Ha': 'Katelynn Harlow',
#  'Eleo Hald': 'Danielle Waldrop',
#  'Semaj P': 'Semaj Plummer',
#  'pDynaa Stele': 'Dayna Steele',
#  'Groeyson cHem': 'Grayson Heim',
#  'KB': 'Keyara Camacho',
#  'C Christion': 'Christion Cohen',
#  'jedidiah clarkson': 'Jedidiah Clarkson',
#  'Jared Gu': 'Jared Gulley',
#  'Ibreivm Sun': 'Ibrahim Sun',
#  'Christy El': 'Christy Elliott',
#  'Elliot John H': 'Elliot Held',
#  'Brnnen Elison': 'Brennen Ellison',
#  'C Matthias': 'Matthias Cordero',
#  'G Brionna': 'Brionna Grimes',
#  'olegdd Fi': 'Holland Foy',
#  'Jeylan zKreger': 'Jaylan Krieger',
#  'Joeqruin Cris': 'Joaquin Crist',
#  'FrenHallstead': 'Frank Halstead',
#  'Kathrine L': 'Kathrine Leone',
#  'Sentiadgo Nadee': 'Santiago Nadeau',
#  'GissalneThorntin': 'Gisselle Thornton',
#  'Ansnae lAhed': 'Annette Ahmed',
#  'KG': 'Keyara Camacho',
#  'Kelen Lyogn': 'Kalen Logan',
#  'HolietndFi': 'Holland Foy',
#  'Robynn Dcki': 'Robyn Dickey',
#  'Tei ltine': 'Tai Kline',
#  'Justyn Go': 'Justyn Goetz',
#  'Alvin John V': 'Alvin Venegas',
#  'Irelhend Barnier': 'Ireland Bernier',
#  'Guillermo John H': 'Guillermo Hackney',
#  'KR': 'Keyara Camacho',
#  'ye epnei': 'Kathrine Leone',
#  'Abegaiv Marx': 'Abagail Marx',
#  'euilermo Heckni': 'Guillermo Hackney',
#  'Jesenieu Peras': 'Jessenia Perales',
#  'fCornliusMeciahs': 'Cornelius Macias',
#  'Kierstin Mi': 'Kierstin Millard',
#  'Allise Buidle': 'Allissa Biddle',
#  'J Kristian': 'Kristian Jansen',
#  'Blbritto Gilaspie': 'Britton Gillespie',
#  'Brennen El': 'Brennen Ellison',
#  'uTeeu Noyes': 'Thea Noyes',
#  'ylti Seels': 'Aylin Seals',
#  'Marcello W': 'Marcello Weber',
#  'Jud Golgdjen': 'Jude Golden',
#  'Jaylan John C': 'Jaylan Conway',
#  'Maesthias Crdro': 'Matthias Cordero',
#  'Phoenix John T': 'Phoenix Thai',
#  'Megaret Kerebs': 'Margaret Krebs',
#  'Delanie John G': 'Delanie Gilbertson',
#  'Judith John H': 'Judith Howland',
#  'eeghan Hughton': 'Reagan Houghton',
#  'guillermo hackney': 'Guillermo Hackney',
#  'D Jaquelin': 'Jaquelin Duran',
#  'Krrla Pris': 'Karla Parris',
#  'Marcello John W': 'Marcello Weber',
#  'Cerloys uivasn': 'Carlos Sullivan',
#  'Kecrstin Romeo': 'Kierstin Romano',
#  'Jonatan John M': 'Jonatan Moses',
#  'karla parris': 'Karla Parris',
#  'Jaylan John K': 'Jaylan Conway',
#  'Dayna St': 'Dayna Steele',
#  'qCehrlos Slian': 'Carlos Sullivan',
#  'Lukes cdGe': 'Lukas McGee',
#  'Rashawn Ba': 'Rashawn Balderas',
#  'Kierstdin Miierd': 'Kierstin Millard',
#  'SevnjanaCornywl': 'Sanjana Cornwell',
#  'Ltresl azsli': 'Latrell Easley',
#  'J Shea': 'Mariel Shearer',
#  'Lihtzy Myea': 'Litzy Moyer',
#  'Cathryn Du': 'Cathryn Duarte',
#  'Annebelelel Mli': 'Annabelle Malloy',
#  'Amqar udolph': 'Amber Rudolph',
#  'AmeiyaSoulano': 'Amaiya Solano',
#  'Merco Rand': 'Marco Rand',
#  'Jessenia P': 'Jessenia Perales',
#  'Alexandrea John S': 'Alexandrea Starnes',
#  'CE': 'Zachery Clancy',
#  'Hgland Fi': 'Holland Foy',
#  'Kobe Berietqos': 'Kobe Barrientos',
#  'Nealya narvin': 'Natalya Garvin',
#  'Afbdulle iRei': 'Abdullah Reddy',
#  'jaylan conway': 'Jaylan Conway',
#  'IrelenadBernir': 'Ireland Bernier',
#  'MericdeloWeber': 'Marcello Weber',
#  'Dayna John S': 'Dayna Steele',
#  'Ainlay oCliton': 'Ainsley Clinton',
#  'Lty Mxoyar': 'Litzy Moyer',
#  'Brone Grimws': 'Brionna Grimes',
#  'Jenebn Rei': 'Eden Ring',
#  'Reena ovmr': 'Reanna Dover',
#  'Mlisty Lvooie': 'Misty Lavoie',
#  'Cristbel Faolon': 'Cristobal Fallon',
#  'Doris Pr': 'Doris Prado',
#  'Irvi Linre': 'Irvin Lira',
#  'Darrion John B': 'Darrion Barrios',
#  'jKei erqier': 'Kenzie Meier',
#  'Wilson S': 'Wilson Slocum',
#  'Kyteyce Cokr': 'Kaycee Coker',
#  'Fren Hmalstekad': 'Frank Halstead',
#  'sPhoanix Tay': 'Phoenix Thai',
#  'Evein Bredli': 'Evelin Bradley',
#  'Rwy Mcnei': 'Ray Mcneely',
#  'JocalyntFtzsimeons': 'Jocelyn Fitzsimmons',
#  'HF': 'Amalia Frost',
#  'AW': 'Annette Ahmed',
#  'Coleman P': 'Coleman Peace',
#  'Anate Ahezd': 'Annette Ahmed',
#  'Lawis Bredlogve': 'Lewis Breedlove',
#  'jonen Bagget': 'Ronan Baggett',
#  'Agail Mahrx': 'Abagail Marx',
#  'Lvusm McGe': 'Lukas McGee',
#  'telista Witeside': 'Kalista Whiteside',
#  'Nore hnyder': 'Nora Snyder',
#  'Britton Gi': 'Britton Gillespie',
#  'Jormdi e': 'Jordin Rodrigues',
#  'AbdeulehHorst': 'Abdullah Horst',
#  'enby Heatn': 'Baby Heaton',
#  'Maranda D': 'Maranda Dunaway',
#  'Reelyna Stwrd': 'Raelyn Steward',
#  'Mallorie Sa': 'Mallorie Saenz',
#  'JK': 'Jaquelin Duran',
#  'Keyle Gorman': 'Keyla Gorman',
#  'Tatum He': 'Tatum Henning',
#  'etrmel fEali': 'Latrell Easley',
#  'Jeyvier reax': 'Javier Breaux',
#  'Gurtevo Mul': 'Gustavo Mull',
#  'Amber Ru': 'Amber Rudolph',
#  'eDria aii': 'Daria Daily',
#  'Jemcy Tipton': 'Jacy Tipton',
#  'Alisong Mcv': 'Alison Mcvey',
#  'emeq Plumeer': 'Semaj Plummer',
#  'Justyn Goatz': 'Justyn Goetz',
#  'lisoon Mcv': 'Alison Mcvey',
#  'Khelen Loaan': 'Kalen Logan',
#  'KV': 'Keyara Camacho',
#  'Brennen E': 'Brennen Ellison',
#  'Jedidiah C': 'Jedidiah Clarkson',
#  'Javier Br': 'Javier Breaux',
#  'ndrawKenfe': 'Andrew Keefe',
#  'Tukar Volk': 'Tucker Volk',
#  'Eene Atvlamirano': 'Elena Altamirano',
#  'LB': 'Irvin Lira',
#  'enie Rei': 'Janie Reddy',
#  'Joalyn Fjitwzsimons': 'Jocelyn Fitzsimmons',
#  'Reymundoeniavides': 'Raymundo Benavides',
#  'AboegailMarx': 'Abagail Marx',
#  'C Gretchen': 'Gretchen Clawson',
#  'uTeiKlie': 'Tai Kline',
#  'DA': 'Annette Ahmed',
#  'enjana Coratnel': 'Sanjana Cornwell',
#  'Herman John T': 'Herman Turley',
#  'Mexim urxk': 'Maxim Turk',
#  'LS': 'Daysha Sapp',
#  'Keylre orman': 'Keyla Gorman',
#  'Geriel Hitchcock': 'Gabriel Hitchcock',
#  'river feliciano': 'River Feliciano',
#  'Graseldu Acuna': 'Griselda Acuna',
#  'Earett Frlod': 'Everett Flood',
#  'Stephon S': 'Stephon Smoot',
#  'G Alexandria': 'Alexandria Galbraith',
#  'Gutevo Mul': 'Gustavo Mull',
#  'Sydnamy owe': 'Sydney Rowe',
#  'Shanna Br': 'Shanna Branch',
#  'Hoalidi hitmre': 'Heidi Whitmore',
#  'Suaphon Burnet': 'Stephon Burnett',
#  'gBb yHeaton': 'Baby Heaton',
#  'dJonethon Legelr': 'Johnathon Leger',
#  'H Janell': 'Janell Hager',
#  'Zoie Mc': 'Zoie McDermott',
#  'D Maranda': 'Maranda Dunaway',
#  'Fernando John S': 'Fernando Segovia',
#  'Evelin Breli': 'Evelin Bradley',
#  'Jeecvon Kirk': 'Jayvon Kirk',
#  'Kelisxa hiteseide': 'Kalista Whiteside',
#  'Lbeeihot': 'Nestor Light',
#  'Kalee John C': 'Kalen Logan',
#  'Ammeli Frst': 'Amalia Frost',
#  'Rteymundoq Zpaa': 'Raymundo Zapata',
#  'hZoi McDermt': 'Zoie McDermott',
#  'taphonw Smot': 'Stephon Smoot',
#  'Amber Coste': 'Amber Costa',
#  'ChestityHuilsi': 'Chastity Hulsey',
#  'CP': 'Zachery Clancy',
#  'pAmeiya Solan': 'Amaiya Solano',
#  'AF': 'Annette Ahmed',
#  'Kierstin John R': 'Kierstin Romano',
#  'S Aylin': 'Aylin Seals',
#  'katelynn harlow': 'Katelynn Harlow',
#  'Arjun Pa': 'Arjun Payne',
#  'uhstevo Mu': 'Gustavo Mull',
#  'Reagan John H': 'Reagan Houghton',
#  'Semira Baer': 'Samira Baer',
#  'Christaion Coan': 'Christion Cohen',
#  'Amine Wrre': 'Amina Ware',
#  'Agmeiya Solan': 'Amaiya Solano',
#  'Fenk Halstean': 'Frank Halstead',
#  'Syde Meerxs': 'Sydnee Mears',
#  'S Alexandrea': 'Alexandrea Starnes',
#  'Grisle Acudna': 'Griselda Acuna',
#  'Bleine Menngzie': 'Blaine Mckenzie',
#  'Chastity John H': 'Chastity Lyle',
#  'Lyndsay S': 'Lyndsay Schuler',
#  'jordi tam': 'Jordi Tam',
#  'Tsesa Smali': 'Tasha Smalley',
#  'Hexza Cawel': 'Hamza Caswell',
#  'B Linda': 'Clyde Lindsay',
#  'christy elliott': 'Christy Elliott',
#  'Jvohny Ti': 'Johnny Toney',
#  'Cristobel Faal': 'Cristobal Fallon',
#  'Codyw Gr': 'Cody Garay',
#  'Kanzii Maeir': 'Kenzie Meier',
#  'S Dayna': 'Dayna Steele',
#  'Everett Fl': 'Everett Flood',
#  'breanne concepcion': 'Breanne Concepcion',
#  'Keyana John G': 'Keyana Grubbs',
#  'enna Stele': 'Dayna Steele',
#  'tasha smalley': 'Tasha Smalley',
#  'etrell Easli': 'Latrell Easley',
#  'Brianna Em': 'Brianna Embry',
#  'Dhruis Machado': 'Darrius Machado',
#  'vier Bpreaux': 'Javier Breaux',
#  'Luisg Semuels': 'Louis Samuels',
#  'Caberlos ulivan': 'Carlos Sullivan',
#  'Jeinh Miligan': 'Jalin Milligan',
#  'Deisha bYon': 'Daisha Yoon',
#  'Cornelus Moecias': 'Cornelius Macias',
#  'Weilson locum': 'Wilson Slocum',
#  'Ktielyn Harlo': 'Katelynn Harlow',
#  'Reskhawn Beadras': 'Rashawn Balderas',
#  'Jsellyn Besro': 'Joselyn Barrow',
#  'elliot held': 'Elliot Held',
#  'Jesnie Percfales': 'Jessenia Perales',
#  'matthias cordero': 'Matthias Cordero',
#  'Jequlin Duraan': 'Jaquelin Duran',
#  'lexenria Galbroaith': 'Alexandria Galbraith',
#  'ohhncy Toni': 'Johnny Toney',
#  'Laxpics Whiti': 'Lexis Whitley',
#  'deangelo neuman': 'Deangelo Neuman',
#  'ZoiasMcDermodt': 'Zoie McDermott',
#  'M Litzy': 'Litzy Moyer',
#  'Stephon John B': 'Stephon Smoot',
#  'FrjenkHalstea': 'Frank Halstead',
#  'H Abdullah': 'Abdullah Horst',
#  'Johson Scsheular': 'Johnson Schuler',
#  'SM': 'Dorothy Mayhew',
#  'Irvin wie': 'Irvin Lira',
#  'Jbyvon irk': 'Jayvon Kirk',
#  'AD': 'Annette Ahmed',
#  'Mckanziej Hitchcorc': 'Mckenzie Hitchcock',
#  'Judith owwlaend': 'Judith Howland',
#  'Luciano John S': 'Lucia Cody',
#  'Danse Minor': 'Denise Minor',
#  'aChrition Cohan': 'Christion Cohen',
#  'ZM': 'Zachery Clancy',
#  'orene Lzmar': 'Lorena Lamar',
#  'Killian John R': 'Killian Ratliff',
#  'fRbyn Guzmen': 'Robyn Guzman',
#  'sana fairbanks': 'Sana Fairbanks',
#  'pJeliniqligan': 'Jalin Milligan',
#  'Annette A': 'Annette Ahmed',
#  'RycliaGomez': 'Rylie Gomez',
#  'JfeyvonKirk': 'Jayvon Kirk',
#  'SB': 'Daysha Sapp',
#  'Theodore John S': 'Theodore Schmidt',
#  'Litzy John M': 'Litzy Moyer',
#  'Ceethyn Duate': 'Cathryn Duarte',
#  'WS': 'Daysha Sapp',
#  'Ibehim Syn': 'Ibrahim Sun',
#  'Jessenia Pe': 'Jessenia Perales',
#  'bKelee Caila': 'Kalee Casillas',
#  'Arutna eyne': 'Arjun Payne',
#  'NL': 'Irvin Lira',
#  'Drius Machsao': 'Darrius Machado',
#  'NethalyaGarvvi': 'Natalya Garvin',
#  'Ronan B': 'Ronan Baggett',
#  'Henrqy Johensen': 'Henry Johansen',
#  'Robn Guadmen': 'Robyn Guzman',
#  'Chriky Elliot': 'Christy Elliott',
#  'Katon Tresjo': 'Kenton Trejo',
#  'JH': 'Jaquelin Duran',
#  'Cristobal Fa': 'Cristobal Fallon',
#  'gLawis Bregove': 'Lewis Breedlove',
#  'Rud Brewmdi': 'Rudy Bradley',
#  'zAbil ovderubias': 'Abril Covarrubias',
#  'Thqe Notyes': 'Thea Noyes',
#  'Gretchein Clewsn': 'Gretchen Clawson',
#  'Jaaequin Crist': 'Joaquin Crist',
#  'Lzine Brenan': 'Linda Brennan',
#  'Jocalynf Fitzsmons': 'Jocelyn Fitzsimmons',
#  'Decrusk Albers': 'Darrius Albers',
#  'buRud Bredli': 'Rudy Bradley',
#  'AylinjSeuls': 'Aylin Seals',
#  'Kenton T': 'Kenton Trejo',
#  'GugilermoHeckni': 'Guillermo Hackney',
#  'Derius wMacyhad': 'Darrius Machado',
#  'KejyceCayrlin': 'Kaycee Carlin',
#  'Latrell Ea': 'Latrell Easley',
#  'Shea Je': 'Shea Jenkins',
#  'Loqriu il': 'Lori Gill',
#  'Netalygy Gavin': 'Natalya Garvin',
#  'Lindereznan': 'Linda Brennan',
#  'DN': 'Jaquelin Duran',
#  'Dorizs redo': 'Doris Prado',
#  'Alexeendia Galraith': 'Alexandria Galbraith',
#  'AllqisseBiqdle': 'Allissa Biddle',
#  'Nency Lamyb': 'Nancy Lamb',
#  'wilson slocum': 'Wilson Slocum',
#  'Hermwe Turfi': 'Herman Turley',
#  'KendrijckVeladz': 'Kendrick Valadez',
#  'Flrnedo Segovmia': 'Fernando Segovia',
#  'Shena ancyh': 'Shanna Branch',
#  'Killien aytif': 'Killian Ratliff',
#  'Amlia fFrost': 'Amalia Frost',
#  'Brittonde Gilspie': 'Britton Gillespie',
#  'Daisha Yo': 'Daisha Yoon',
#  'qMistyLevoie': 'Misty Lavoie',
#  'Alize Do': 'Alize Dodd',
#  'Siege Scrock': 'Sage Schrock',
#  'adan goetz': 'Adan Goetz',
#  'Kerltb Paris': 'Karla Parris',
#  'Deerfo White': 'Dario White',
#  'Ciera John A': 'Ciera Almanza',
#  'brionna grimes': 'Brionna Grimes',
#  'Jezmyon Syhid': 'Jazmyn Schmid',
#  'Allen M': 'Allen McPherson',
#  'Cornelius Mejcias': 'Cornelius Macias',
#  'obdynf Guzmen': 'Robyn Guzman',
#  'E Alina': 'Alina Ervin',
#  'Keypna Grubs': 'Keyana Grubbs',
#  'Jrdo Teum': 'Jordi Tam',
#  'Abzril Cvperubias': 'Abril Covarrubias',
#  'Loi giol': 'Lori Gill',
#  'Ray Mc': 'Ray Mcneely',
#  'Leh Roct': 'Leah Root',
#  'Stephon Sm': 'Stephon Smoot',
#  'Allsse Biadle': 'Allissa Biddle',
#  'Ashtyn Bvnezmin': 'Ashtyn Benjamin',
#  'MC': 'Zachery Clancy',
#  'Lori G': 'Lori Gill',
#  'louis samuels': 'Louis Samuels',
#  'Keyce arlin': 'Kaycee Carlin',
#  'Chrsty Ellwiot': 'Christy Elliott',
#  'Nor Sydejr': 'Nora Snyder',
#  'Alearh Chishowlm': 'Alannah Chisholm',
#  'Theodore Sc': 'Theodore Schmidt',
#  'Devyn Ew': 'Devyn Ewing',
#  'Jevioer Breux': 'Javier Breaux',
#  'Eqre ord': 'Ezra Lord',
#  'Blaine Mc': 'Blaine Mckenzie',
#  'Awnnate Ahmt': 'Annette Ahmed',
#  'Alina John E': 'Alina Ervin',
#  'Sthahpon Smot': 'Stephon Smoot',
#  'EF': 'Amalia Frost',
#  'Mckazie Hitchqcoick': 'Mckenzie Hitchcock',
#  'Joslyffn Berw': 'Joselyn Barrow',
#  'Reewa Dovr': 'Reanna Dover',
#  'kShee Jekirns': 'Shea Jenkins',
#  'Alann McPhersn': 'Allen McPherson',
#  'Kethrine weonae': 'Kathrine Leone',
#  'Abril Co': 'Abril Covarrubias',
#  'qLitzy Myar': 'Litzy Moyer',
#  'Merganda Dunawi': 'Maranda Dunaway',
#  'Christiwon Cooa': 'Christion Cohen',
#  'Ameiya Slasno': 'Amaiya Solano',
#  'Tei Kulci': 'Tai Kline',
#  'raymundo benavides': 'Raymundo Benavides',
#  'Holeqnd F': 'Holland Foy',
#  'ilplien Ralif': 'Killian Ratliff',
#  'Thee kNyes': 'Thea Noyes',
#  'Ashtyn Be': 'Ashtyn Benjamin',
#  'Amalia John F': 'Amalia Frost',
#  'Keri Cetrir': 'Keri Carrier',
#  'LL': 'Irvin Lira',
#  'LM': 'Dorothy Mayhew',
#  'Keri Ceiuer': 'Keri Carrier',
#  'EL': 'Brianna Embry',
#  'Haidi Whitmre': 'Heidi Whitmore',
#  'hamza caswell': 'Hamza Caswell',
#  'Ketelyns Harlow': 'Katelynn Harlow',
#  'JF': 'Jaquelin Duran',
#  'kGredy qSampe': 'Grady Sample',
#  'G Lori': 'Jordin Rodrigues',
#  'Kelstd Whiteside': 'Kalista Whiteside',
#  'S Warren': 'Denisse Warden',
#  'Geret Cgockrel': 'Garret Cockrell',
#  'santiago nadeau': 'Santiago Nadeau',
#  'AlanuMcuPhersn': 'Allen McPherson',
#  'Brannen Elrison': 'Brennen Ellison',
#  'Mrrczelo Weber': 'Marcello Weber',
#  'Lori Gil': 'Lori Gill',
#  'JG': 'Jaquelin Duran',
#  'nezlise Dwietz': 'Annalise Dietz',
#  'SoegeSchrpock': 'Sage Schrock',
#  'Juqstyn oatz': 'Justyn Goetz',
#  'jArjun Pyne': 'Arjun Payne',
#  'Allise Bidle': 'Allissa Biddle',
#  'Kaycee Co': 'Kaycee Coker',
#  'Gerre Cyockrel': 'Garret Cockrell',
#  'hTysvhewn Esino': 'Tyshawn Espino',
#  'iera Jauregjy': 'Kiara Jauregui',
#  'Nancy L': 'Nancy Lamb',
#  'Marco R': 'Marco Rand',
#  'Jordi Ta': 'Jordi Tam',
#  'Yisroahl isk': 'Yisroel Sisk',
#  'Sena cairbanks': 'Sana Fairbanks',
#  'Jocwalyn Fitzsimons': 'Jocelyn Fitzsimmons',
#  'gJrrett Mui': 'Jarrett Murry',
#  'Ryia Gomenz': 'Rylie Gomez',
#  'Rudy Br': 'Rudy Bradley',
#  'Txesha Sali': 'Tasha Smalley',
#  'Edan Rig': 'Eden Ring',
#  'Kierfsti Miwerd': 'Kierstin Millard',
#  'Jdidieh Clxarkson': 'Jedidiah Clarkson',
#  'Reeyn oStewardd': 'Raelyn Steward',
#  'Clyde John L': 'Clyde Bolin',
#  'Stapgho Smot': 'Stephon Smoot',
#  'Deegseo Neuman': 'Deangelo Neuman',
#  'jeilyn Seward': 'Cailyn Seward',
#  'Kceyeoa Grus': 'Keyana Grubbs',
#  'Gredy oSamle': 'Grady Sample',
#  'JeylanKrreger': 'Jaylan Krieger',
#  'Reegqan Hoiughto': 'Reagan Houghton',
#  'iverFelihqcieno': 'River Feliciano',
#  'Igbeim Sun': 'Ibrahim Sun',
#  'Chelesgy Den': 'Chelsey Dean',
#  'Reymundo Benbvides': 'Raymundo Benavides',
#  'Grejdy Sampqe': 'Grady Sample',
#  'Dengeo hNfeuman': 'Deangelo Neuman',
#  'Daxter Dune': 'Dexter Dunne',
#  'Amneliia Frot': 'Amalia Frost',
#  'sAbegail mMrx': 'Abagail Marx',
#  'Jecy Tapton': 'Jacy Tipton',
#  'Axlizza Do': 'Alize Dodd',
#  'eTesha Smali': 'Tasha Smalley',
#  'Alpison Mvi': 'Alison Mcvey',
#  'Everett John F': 'Everett Flood',
#  'Jeylan Kriger': 'Jaylan Krieger',
#  'amaiya solano': 'Amaiya Solano',
#  'Leah John R': 'Leah Root',
#  'Kanzeo Meier': 'Kenzie Meier',
#  'Justnq Goatz': 'Justyn Goetz',
#  'Johnson Sc': 'Johnson Schuler',
#  'Saydnay ow': 'Sydney Rowe',
#  'KrieraJaurgy': 'Kiara Jauregui',
#  'T Phoenix': 'Phoenix Fontaine',
#  'Heidi W': 'Heidi Whitmore',
#  'Crystew Leavi': 'Crystal Leavitt',
#  'Joeqsuin Crist': 'Joaquin Crist',
#  'L Lorena': 'Charlotte Lorenzo',
#  'brehidm Sun': 'Ibrahim Sun',
#  'Sserenity Cestlo': 'Serenity Castillo',
#  'Rey Mcnm': 'Ray Mcneely',
#  'CristonbelFalon': 'Cristobal Fallon',
#  'Clyyd Lindsi': 'Clyde Lindsay',
#  'iGeson Hexim': 'Grayson Heim',
#  'Galilea Vi': 'Galilea Villasenor',
#  'ciera almanza': 'Ciera Almanza',
#  'Rwudy Brdli': 'Rudy Bradley',
#  'Jeelifn Milin': 'Jalin Milligan',
#  'kLouis Sexmels': 'Louis Samuels',
#  'Dierqa Dai': 'Daria Daily',
#  'Erett Flngod': 'Everett Flood',
#  'Johnathon Le': 'Johnathon Leger',
#  'Cody ceri': 'Cody Medina',
#  'ronan baggett': 'Ronan Baggett',
#  'JenikeRe': 'Janie Reddy',
#  'Arjukn Peyn': 'Arjun Payne',
#  'rioneikGrimes': 'Brionna Grimes',
#  'Alenah Cphnsholm': 'Alannah Chisholm',
#  'Janell H': 'Janell Hager',
#  'EN': 'Brianna Embry',
#  'zTysvhewn Epio': 'Tyshawn Espino',
#  'aJein Miltiga': 'Jalin Milligan',
#  'Nancy La': 'Nancy Lamb',
#  'Dektota oyer': 'Dakotah Boyer',
#  'echeryp Schrakder': 'Zachery Schrader',
#  'pSemejj Plumr': 'Semaj Plummer',
#  'erenithy Cemstilo': 'Serenity Castillo',
#  'Annte qjAhmed': 'Annette Ahmed',
#  'AnelniseDietz': 'Annalise Dietz',
#  'Aislay Clenton': 'Ainsley Clinton',
#  'AB': 'Annette Ahmed',
#  'Justyr lGoatz': 'Justyn Goetz',
#  'Guilermo Hpekni': 'Guillermo Hackney',
#  'H Mckenzie': 'Blaine Mckenzie',
#  'LyjndseSchulezr': 'Lyndsay Schuler',
#  'Milod Grnfield': 'Milo Greenfield',
#  'G Milo': 'Jacey Dillon',
#  'Gusutevo Ml': 'Gustavo Mull',
#  'Dxtr Durne': 'Dexter Dunne',
#  'Henry Johense': 'Henry Johansen',
#  'Hoaidi Whitozre': 'Heidi Whitmore',
#  'gelin Milign': 'Jalin Milligan',
#  'Alexendrea Staxnes': 'Alexandrea Starnes',
#  'Justp Goathz': 'Justyn Goetz',
#  'irvin lira': 'Irvin Lira',
#  'Judith Ho': 'Judith Howland',
#  'Brionna Gr': 'Brionna Grimes',
#  'lexekndrea Starns': 'Alexandrea Starnes',
#  'S Raelyn': 'Raelyn Steward',
#  'Ayln Sjeepls': 'Aylin Seals',
#  'Aen Goedtz': 'Adan Goetz',
#  'Coemexn Peae': 'Coleman Peace',
#  'eden ring': 'Eden Ring',
#  'IrelenndBenier': 'Ireland Bernier',
#  'itzky Moyar': 'Litzy Moyer',
#  'warren schofield': 'Warren Schofield',
#  'Santiago John N': 'Santiago Nadeau',
#  'Jenny Ba': 'Jenny Barksdale',
#  'xKanton Tejo': 'Kenton Trejo',
#  'Reymundo kenavides': 'Raymundo Benavides',
#  'Alenah hmsholm': 'Alannah Chisholm',
#  'Qruinten Teylo': 'Quinton Taylor',
#  'awis Bredlave': 'Lewis Breedlove',
#  'luciano sims': 'Luciano Sims',
#  'Jenny John B': 'Henry Johansen',
#  'Derus Abferhs': 'Darrius Albers',
#  'Deengelo Neumsn': 'Deangelo Neuman',
#  'Griselda John A': 'Griselda Acuna',
#  'BrioneGrimyes': 'Brionna Grimes',
#  'Giovanna John F': 'Giovanna Fugate',
#  'eAita Dod': 'Alize Dodd',
#  'HW': 'Branson Harman',
#  'Kethinem Leone': 'Kathrine Leone',
#  'Marco John R': 'Marco Rand',
#  'emdej Plumer': 'Semaj Plummer',
#  'Ali Vejneges': 'Alvin Venegas',
#  'Deisha Yuvn': 'Daisha Yoon',
#  'Robyd Guqmen': 'Robyn Guzman',
#  'Jevievr Breau': 'Javier Breaux',
#  'Jeierw Brejux': 'Javier Breaux',
#  'Jediieh yClarkson': 'Jedidiah Clarkson',
#  'GiovenaFcugate': 'Giovanna Fugate',
#  'qilo Gxranfield': 'Milo Greenfield',
#  'oAdalvine eni': 'Adeline Henry',
#  'Mercelo Wbeer': 'Marcello Weber',
#  'Dnnise Mnor': 'Denise Minor',
#  'Alin enegezs': 'Alvin Venegas',
#  'Natalya John G': 'Natalya Garvin',
#  'Mireye ofdfrei': 'Mireya Godfrey',
#  'Gredy Satmepe': 'Grady Sample',
#  'KE': 'Keyara Camacho',
#  'ohnetan Mose': 'Jonatan Moses',
#  'samira baer': 'Samira Baer',
#  'Chrisison Coan': 'Christion Cohen',
#  'eed cGuvli': 'Jared Gulley',
#  'SS': 'Daysha Sapp',
#  'Sage Sc': 'Sage Schrock',
#  'Evererof Cronii': 'Everardo Cronin',
#  'clyde bolin': 'Clyde Bolin',
#  'Aya John K': 'Amaris Jones',
#  'Gert ioCockrel': 'Garret Cockrell',
#  'LoeehRt': 'Genevieve Ratliff',
#  'Kobe Besriento': 'Kobe Barrientos',
#  'ecse Franz': 'Jase Franz',
#  'Jeier cBrewaux': 'Javier Breaux',
#  'HbolenFi': 'Gwendolyn Findley',
#  'Dyna Sttlae': 'Dayna Steele',
#  'AlineErvik': 'Alina Ervin',
#  'Irvin John L': 'Irvin Lira',
#  'Herman Tu': 'Herman Turley',
#  'mKerrla aris': 'Karla Parris',
#  'Abdullah R': 'Abdullah Reddy',
#  'Daria D': 'Daria Daily',
#  'KilliemnRatlif': 'Killian Ratliff',
#  'Kaycee Ca': 'Kaycee Carlin',
#  'JozequinCrist': 'Joaquin Crist',
#  'Ayln Seels': 'Aylin Seals',
#  'qKetelyfn Harw': 'Katelynn Harlow',
#  'Ambar Rudlph': 'Amber Rudolph',
#  'CchelseybDeen': 'Chelsey Dean',
#  'iee Alsmanza': 'Ciera Almanza',
#  'Dakotah John B': 'Dakotah Boyer',
#  'Bredle kMazur': 'Bradley Mazur',
#  'Kierstn Milcerbd': 'Kierstin Millard',
#  'Thwaodore Scfmidt': 'Theodore Schmidt',
#  'etriciva Gros': 'Patricia Gross',
#  'eyn Stenlbe': 'Dayna Steele',
#  'Cohnelius Mecias': 'Cornelius Macias',
#  'litzy moyer': 'Litzy Moyer',
#  'ogBriena mi': 'Brianna Embry',
#  'Asjhtyn Benjegmn': 'Ashtyn Benjamin',
#  'Yisrol uSisk': 'Yisroel Sisk',
#  'benel Hager': 'Janell Hager',
#  'tyshawn espino': 'Tyshawn Espino',
#  'GF': 'Amalia Frost',
#  'Warren John S': 'Warren Schofield',
#  'pNetalya arvin': 'Natalya Garvin',
#  'C Kalee': 'Carlee Pearce',
#  'Ibrahim Su': 'Ibrahim Sun',
#  'eylan Kprieger': 'Jaylan Krieger',
#  'Alan McPgheson': 'Allen McPherson',
#  'Joselyn John B': 'Joselyn Barrow',
#  'Jhvon Kirk': 'Jayvon Kirk',
#  'Klfena Logan': 'Kalen Logan',
#  'Loene Lamiar': 'Lorena Lamar',
#  'Sejana Cdornzwel': 'Sanjana Cornwell',
#  'kristpien Jansen': 'Kristian Jansen',
#  'entiagqoe Naeau': 'Santiago Nadeau',
#  'Jarrett John M': 'Jarrett Murry',
#  'Justyn G': 'Justyn Goetz',
#  'Cristopeol Falon': 'Cristobal Fallon',
#  'rSege Scrck': 'Sage Schrock',
#  'jenny barksdale': 'Jenny Barksdale',
#  'Reegn Houghton': 'Reagan Houghton',
#  'DM': 'Jaquelin Duran',
#  'See Guthrbie': 'Sean Guthrie',
#  'Joequmn Crist': 'Joaquin Crist',
#  'eytMcnei': 'Ray Mcneely',
#  'Jerrettb Mui': 'Jarrett Murry',
#  'Ryla cGmetz': 'Rylie Gomez',
#  'LR': 'Genevieve Ratliff',
#  'Mckanzie Hichcocok': 'Mckenzie Hitchcock',
#  'Abdullah Re': 'Abdullah Reddy',
#  'Irehwim Saun': 'Ibrahim Sun',
#  'Bradley Ma': 'Bradley Mazur',
#  'Kea Grenfiejld': 'Kala Greenfield',
#  'Chelsey John D': 'Chelsey Dean',
#  'B Javier': 'Javier Breaux',
#  'kenton trejo': 'Kenton Trejo',
#  'A Darrius': 'Darrius Machado',
#  'ouias Semuels': 'Louis Samuels',
#  'M Kierstin': 'Kierstin Millard',
#  'qDeisa Yon': 'Daisha Yoon',
#  'Keye Carnglin': 'Kaycee Carlin',
#  'Kellie Evere': 'Kallie Everett',
#  'Delnive Gilbefrtsn': 'Delanie Gilbertson',
#  'Alse Bertzrend': 'Alyse Bertrand',
#  'ypdne Meelrs': 'Sydnee Mears',
#  'kierstin romano': 'Kierstin Romano',
#  'Killian R': 'Killian Ratliff',
#  'Guillermo Ha': 'Guillermo Hackney',
#  'Wxre Schofield': 'Warren Schofield',
#  'Chrity Eliiot': 'Christy Elliott',
#  'njate Ahmed': 'Annette Ahmed',
#  'Biensa Emi': 'Brianna Embry',
#  'Jacey Di': 'Jacey Dillon',
#  'Aba sRudolph': 'Amber Rudolph',
#  'brennen ellison': 'Brennen Ellison',
#  'W Amina': 'Amina Ware',
#  'Rey Mdcnei': 'Ray Mcneely',
#  'K Kayleigh': 'Kayleigh Koenig',
#  'Frank H': 'Frank Halstead',
#  'Lks cMcGge': 'Lukas McGee',
#  'Rylie G': 'Rylie Gomez',
#  'jude golden': 'Jude Golden',
#  'JC': 'Zachery Clancy',
#  'G Cody': 'Lucia Cody',
#  'RonenynBaget': 'Ronan Baggett',
#  'ouis fSemuels': 'Louis Samuels',
#  'Mongseret oamax': 'Monserrat Lomax',
#  'Sanjana John C': 'Sanjana Cornwell',
#  'Jcalydn Fitzsimon': 'Jocelyn Fitzsimmons',
#  'Ntralya Garvin': 'Natalya Garvin',
#  'Remundxo Zapata': 'Raymundo Zapata',
#  'LaxisWitlhi': 'Lexis Whitley',
#  'Gpre Sample': 'Grady Sample',
#  'Deengelo Nepummn': 'Deangelo Neuman',
#  'Lindep Brena': 'Linda Brennan',
#  'Santiago Na': 'Santiago Nadeau',
#  'Alexendimz Galbraith': 'Alexandria Galbraith',
#  'Sege Schxro': 'Sage Schrock',
#  'Chelse Deen': 'Chelsey Dean',
#  'Cirre Aldmanza': 'Ciera Almanza',
#  'Jmes Pavtrck': 'James Patrick',
#  'Bleieneh Mckenzi': 'Blaine Mckenzie',
#  'Pgoanix Th': 'Phoenix Thai',
#  'Gabriel H': 'Gabriel Hitchcock',
#  'CristyobelFalun': 'Cristobal Fallon',
#  'CeristionnCohan': 'Christion Cohen',
#  'Quintn rxTeylor': 'Quinton Taylor',
#  'Kobe Berintos': 'Kobe Barrientos',
#  'Etdn Rig': 'Eden Ring',
#  'Lacis uWhitli': 'Lexis Whitley',
#  'Kanze Meivaer': 'Kenzie Meier',
#  'KelsieSetgre': 'Kelsie Segura',
#  'Chanel P': 'Chanel Pickett',
#  'Corelius Mecits': 'Cornelius Macias',
#  'AM': 'Annette Ahmed',
#  'Amaiya So': 'Amaiya Solano',
#  'Keyri Cerier': 'Keri Carrier',
#  'Klob Berienteos': 'Kobe Barrientos',
#  'Hremen Trli': 'Herman Turley',
#  'Melpor Saenz': 'Mallorie Saenz',
#  'Shea J': 'Shea Jenkins',
#  'hselsey Deen': 'Chelsey Dean',
#  'Roena qMcqair': 'Roxanna McNair',
#  'Semirsa Baer': 'Samira Baer',
#  'Clhenel uPickt': 'Chanel Pickett',
#  'wGuilermo Hecni': 'Guillermo Hackney',
#  'Semekj bPlmer': 'Semaj Plummer',
#  'Evelin dredl': 'Evelin Bradley',
#  'Joselyn Ba': 'Joselyn Barrow',
#  'Abril John C': 'Abril Covarrubias',
#  'Dekotah Boyeqt': 'Dakotah Boyer',
#  'ukes McGde': 'Lukas McGee',
#  'amina ware': 'Amina Ware',
#  'L Kalen': 'Kalen Logan',
#  'Gdelilea Vlasenor': 'Galilea Villasenor',
#  'Jedidiah John C': 'Jedidiah Clarkson',
#  'RioynDibcki': 'Robyn Dickey',
#  'Alannah Ch': 'Alannah Chisholm',
#  'doris prado': 'Doris Prado',
#  'Refyundo Zapata': 'Raymundo Zapata',
#  'Chastity H': 'Chastity Hulsey',
#  'Kellievezret': 'Kallie Everett',
#  'Dderid Whte': 'Dario White',
#  'CherismdWidlbur': 'Charisma Wilbur',
#  'P Semaj': 'Semaj Plummer',
#  'Jenenl Haegr': 'Janell Hager',
#  'equellin cDuran': 'Jaquelin Duran',
#  'Mckenzie John H': 'Mckenzie Finn',
#  'Hxemza Caswel': 'Hamza Caswell',
#  'Jrnel yHage': 'Janell Hager',
#  'Gabriel Hi': 'Gabriel Hitchcock',
#  'Ivin Lirte': 'Irvin Lira',
#  'Jese Fdanz': 'Jase Franz',
#  'ES': 'Daysha Sapp',
#  'Keles Gormn': 'Keyla Gorman',
#  'alycia woodard': 'Alycia Woodard',
#  'Alexandria John G': 'Alexandria Galbraith',
#  'Killien Ratlif': 'Killian Ratliff',
#  'Amdbber Cose': 'Amber Costa',
#  'Serenity Cesnil': 'Serenity Castillo',
#  'Sydney R': 'Sydney Rowe',
#  'Cyida Lindosi': 'Clyde Lindsay',
#  'leRbyn Dicki': 'Robyn Dickey',
#  'Crwstbel Falon': 'Cristobal Fallon',
#  'Sntiago bNadeau': 'Santiago Nadeau',
#  'Tuara Voxlk': 'Tucker Volk',
#  'Jeny Berksqda': 'Jenny Barksdale',
#  'Tate John B': 'Tate Blum',
#  'Cemily cSeward': 'Cailyn Seward',
#  'Mnnet elace': 'Monet Wallace',
#  'F Sana': 'Susana Healey',
#  'Raeymundo Benavies': 'Raymundo Benavides',
#  'cody garay': 'Cody Garay',
#  'Deenlgelo Neupa': 'Deangelo Neuman',
#  'yev Keneyi': 'Aya Kennedy',
#  'Kiestmin Romno': 'Kierstin Romano',
#  'Briena Embi': 'Brianna Embry',
#  'Jqeyla Krielge': 'Jaylan Krieger',
#  'dey tMcnei': 'Cody Medina',
#  'Alyse B': 'Alyse Bertrand',
#  'Dekotawh Boyr': 'Dakotah Boyer',
#  'Mergco Rand': 'Marco Rand',
#  'Evarevrtt Flo': 'Everett Flood',
#  'H Baby': 'Dania Babb',
#  'Ednan Rino': 'Eden Ring',
#  'Craystel Leavi': 'Crystal Leavitt',
#  'Josaf Fni': 'Josef Finney',
#  'Ltzoy oyar': 'Litzy Moyer',
#  'DeriusMaachdo': 'Darrius Machado',
#  'Kelsie Seghue': 'Kelsie Segura',
#  'Gustev Mucvl': 'Gustavo Mull',
#  'Liori il': 'Lori Gill',
#  'T Jacy': 'Jacey Dillon',
#  'JekonqVandyke': 'Jadon Vandyke',
#  'DerrionBasios': 'Darrion Barrios',
#  'Jzoquin Crisit': 'Joaquin Crist',
#  'Gsiselde Acuna': 'Griselda Acuna',
#  'Lawis Brdjlov': 'Lewis Breedlove',
#  'Jarrett Mu': 'Jarrett Murry',
#  'Shena Branch': 'Shanna Branch',
#  'Killin Ratlisf': 'Killian Ratliff',
#  'helseyp Den': 'Chelsey Dean',
#  'Krbi Cerier': 'Keri Carrier',
#  'xAlin Ervin': 'Alina Ervin',
#  'alexandrea starnes': 'Alexandrea Starnes',
#  'veluin Breli': 'Evelin Bradley',
#  'Gusitev ul': 'Gustavo Mull',
#  'Phxanix Thy': 'Phoenix Thai',
#  'kJocalyn Fitsimos': 'Jocelyn Fitzsimmons',
#  'Kalen L': 'Kalen Logan',
#  'Kthrine Leeone': 'Kathrine Leone',
#  'IbrehimuSku': 'Ibrahim Sun',
#  'Mildlo Ganfield': 'Milo Greenfield',
#  'Dehba Yon': 'Daisha Yoon'}

# %%
len(name_club_dict)
# Out:
# 943

# %%
df_club['Name'].nunique()
# Out:
# 987

# %%
df_club['Name'] = df_club['Name'].replace(name_club_dict)

# %%
df_club['Name'].nunique()
# Out:
# 304

# %%
df_club['Role'].value_counts()
# Out:
# Participant    1001
# organiser_1       9
# organiser_5       9
# organiser_3       9
# organiser_4       9
# organiser_2       9
# Name: Role, dtype: int64

# %%
df_club['Name'].isnull().sum()
# Out:
# 0

# %%
df_club['Name']
# Out:
# 0        Darien Martens
# 1          Sage Schrock
# 2          Alison Mcvey
# 3        Kiara Jauregui
# 4             Tate Blum
#              ...
# 1041        Kalen Logan
# 1042     Kathrine Leone
# 1043        Ibrahim Sun
# 1044    Milo Greenfield
# 1045        Daisha Yoon
# Name: Name, Length: 1046, dtype: object

# %%
df_orgmeta=pd.merge(df_meta,df_org,how='left',on='Name')
df_orgmeta
# Out:
#                 Name          ID Fest_Name         Role
# 0      Annette Ahmed  18XJ1A0100    fest_2  organiser_4
# 1     Zachery Clancy  18XJ1A0101       NaN          NaN
# 2     Jaquelin Duran  18XJ1A0102       NaN          NaN
# 3    Orlando Clemens  18XJ1A0103       NaN          NaN
# 4     Dorothy Mayhew  18XJ1A0104       NaN          NaN
# ..               ...         ...       ...          ...
# 495     Andrew Keefe  17XJ1A0345       NaN          NaN
# 496    Valeria Quinn  17XJ1A0346       NaN          NaN
# 497   Joselyn Barrow  17XJ1A0347       NaN          NaN
# 498     Yisroel Sisk  17XJ1A0348       NaN          NaN
# 499     Natalia Huff  17XJ1A0349       NaN          NaN
#
# [500 rows x 4 columns]

# %%
df_orgmeta.isnull().sum()
# Out:
# Name           0
# ID             0
# Fest_Name    480
# Role         480
# dtype: int64

# %%
df_replacement=df_orgmeta

# %%
df_orgmeta.dtypes
# Out:
# Name         object
# ID           object
# Fest_Name    object
# Role         object
# dtype: object

# %%
df_orgmeta=df_orgmeta.dropna()

# %%
df_orgmeta
# Out:
#                    Name          ID Fest_Name          Role
# 0         Annette Ahmed  18XJ1A0100    fest_2   organiser_4
# 7           Aya Kennedy  18XJ1A0107    fest_2   organiser_1
# 14    Genevieve Ratliff  18XJ1A0114    fest_1   organiser_5
# 34        Starr Hammond  18XJ1A0134    fest_2   organiser_2
# 88       Evelin Bradley  18XJ1A0188    fest_1   organiser_1
# 224     River Feliciano  18XJ1A0324    fest_1   organiser_2
# 231         Daria Daily  18XJ1A0331    fest_1   organiser_3
# 235           Jordi Tam  18XJ1A0335    fest_1   organiser_4
# 265       Stephon Smoot  17XJ1A0115    fest_2   organiser_3
# 276    Rashawn Balderas  17XJ1A0126    fest_2   organiser_5
# 282      Abdullah Horst  17XJ1A0132    fest_1   organiser_6
# 299         Aylin Seals  17XJ1A0149    fest_2   organiser_6
# 305   Sebastien Hickman  17XJ1A0155    fest_2   organiser_7
# 317     Blaine Mckenzie  17XJ1A0167    fest_1   organiser_7
# 345    Gretchen Clawson  17XJ1A0195    fest_2   organiser_8
# 363      Ashanti Koenig  17XJ1A0213    fest_1   organiser_8
# 377      Zoie McDermott  17XJ1A0227    fest_2   organiser_9
# 380  Delanie Gilbertson  17XJ1A0230    fest_2  organiser_10
# 406        Leona Cabral  17XJ1A0256    fest_1   organiser_9
# 467      Perry Perryman  17XJ1A0317    fest_1  organiser_10

# %%
df_part.head()
# Out:
#   Fest_Name             Name            Event
# 0    fest_1     Jayna Rowley   fest_1_event_9
# 1    fest_1     Candy Duenas   fest_1_event_4
# 2    fest_2   Jaquelin Duran   fest_2_event_1
# 3    fest_1  Kaliyah Hidalgo   fest_1_event_4
# 4    fest_2      Elaine Sell  fest_2_event_15

# %%
df_part['Fest_Name'].value_counts()
# Out:
# fest_2    2745
# fest_1    2024
# Name: Fest_Name, dtype: int64

# %%
df_metaclub=pd.merge(df_meta,df_club,how='left',on='Name')

# %%
df_metaclub
# Out:
#                Name          ID Club_Name           Event         Role
# 0     Annette Ahmed  18XJ1A0100    club_2  club_2_event_2  Participant
# 1     Annette Ahmed  18XJ1A0100    club_1  club_1_event_1  organiser_1
# 2     Annette Ahmed  18XJ1A0100    club_1  club_1_event_2  Participant
# 3     Annette Ahmed  18XJ1A0100    club_1  club_1_event_2  organiser_1
# 4     Annette Ahmed  18XJ1A0100    club_1  club_1_event_3  Participant
# ...             ...         ...       ...             ...          ...
# 1230   Yisroel Sisk  17XJ1A0348    club_1  club_1_event_1  Participant
# 1231   Yisroel Sisk  17XJ1A0348    club_2  club_2_event_1  Participant
# 1232   Yisroel Sisk  17XJ1A0348    club_2  club_2_event_2  Participant
# 1233   Yisroel Sisk  17XJ1A0348    club_3  club_3_event_1  Participant
# 1234   Natalia Huff  17XJ1A0349       NaN             NaN          NaN
#
# [1235 rows x 5 columns]

# %%
df_metaclub.isnull().sum()
# Out:
# Name           0
# ID             0
# Club_Name    240
# Event        240
# Role         240
# dtype: int64

# %%
df_metapart=pd.merge(df_meta,df_part,how='left',on='Name')
df_metapart['Role']='Participant'
df_metapart
# Out:
#                Name          ID Fest_Name            Event         Role
# 0     Annette Ahmed  18XJ1A0100    fest_2  fest_2_event_10  Participant
# 1     Annette Ahmed  18XJ1A0100    fest_2   fest_2_event_3  Participant
# 2     Annette Ahmed  18XJ1A0100    fest_2   fest_2_event_8  Participant
# 3     Annette Ahmed  18XJ1A0100    fest_2   fest_2_event_4  Participant
# 4     Annette Ahmed  18XJ1A0100    fest_2  fest_2_event_13  Participant
# ...             ...         ...       ...              ...          ...
# 4645   Natalia Huff  17XJ1A0349    fest_2   fest_2_event_1  Participant
# 4646   Natalia Huff  17XJ1A0349    fest_2  fest_2_event_12  Participant
# 4647   Natalia Huff  17XJ1A0349    fest_1   fest_1_event_5  Participant
# 4648   Natalia Huff  17XJ1A0349    fest_2   fest_2_event_7  Participant
# 4649   Natalia Huff  17XJ1A0349    fest_2   fest_2_event_2  Participant
#
# [4650 rows x 5 columns]

# %%
df_metapart.isnull().sum()
# Out:
# Name           0
# ID             0
# Fest_Name    115
# Event        115
# Role           0
# dtype: int64

# %%
df_orgmeta
# Out:
#                    Name          ID Fest_Name          Role
# 0         Annette Ahmed  18XJ1A0100    fest_2   organiser_4
# 7           Aya Kennedy  18XJ1A0107    fest_2   organiser_1
# 14    Genevieve Ratliff  18XJ1A0114    fest_1   organiser_5
# 34        Starr Hammond  18XJ1A0134    fest_2   organiser_2
# 88       Evelin Bradley  18XJ1A0188    fest_1   organiser_1
# 224     River Feliciano  18XJ1A0324    fest_1   organiser_2
# 231         Daria Daily  18XJ1A0331    fest_1   organiser_3
# 235           Jordi Tam  18XJ1A0335    fest_1   organiser_4
# 265       Stephon Smoot  17XJ1A0115    fest_2   organiser_3
# 276    Rashawn Balderas  17XJ1A0126    fest_2   organiser_5
# 282      Abdullah Horst  17XJ1A0132    fest_1   organiser_6
# 299         Aylin Seals  17XJ1A0149    fest_2   organiser_6
# 305   Sebastien Hickman  17XJ1A0155    fest_2   organiser_7
# 317     Blaine Mckenzie  17XJ1A0167    fest_1   organiser_7
# 345    Gretchen Clawson  17XJ1A0195    fest_2   organiser_8
# 363      Ashanti Koenig  17XJ1A0213    fest_1   organiser_8
# 377      Zoie McDermott  17XJ1A0227    fest_2   organiser_9
# 380  Delanie Gilbertson  17XJ1A0230    fest_2  organiser_10
# 406        Leona Cabral  17XJ1A0256    fest_1   organiser_9
# 467      Perry Perryman  17XJ1A0317    fest_1  organiser_10

# %%
df_onlyfest=pd.merge(df_orgmeta,df_metapart,how='outer',on=['Name','Role','ID','Fest_Name'])
df_onlyfest
# Out:
#                    Name          ID Fest_Name         Role            Event
# 0         Annette Ahmed  18XJ1A0100    fest_2  organiser_4              NaN
# 1           Aya Kennedy  18XJ1A0107    fest_2  organiser_1              NaN
# 2     Genevieve Ratliff  18XJ1A0114    fest_1  organiser_5              NaN
# 3         Starr Hammond  18XJ1A0134    fest_2  organiser_2              NaN
# 4        Evelin Bradley  18XJ1A0188    fest_1  organiser_1              NaN
# ...                 ...         ...       ...          ...              ...
# 4665       Natalia Huff  17XJ1A0349    fest_1  Participant  fest_1_event_13
# 4666       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_4
# 4667       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_3
# 4668       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_8
# 4669       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_5
#
# [4670 rows x 5 columns]

# %%
df_onlyfest.isnull().sum()
# Out:
# Name           0
# ID             0
# Fest_Name    115
# Role           0
# Event        135
# dtype: int64

# %%
df_onlyfest['participated']=True
for i in range(0,20):
    df_onlyfest['participated'][i]=False
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_onlyfest
# Out:
#                    Name          ID Fest_Name         Role            Event  \
# 0         Annette Ahmed  18XJ1A0100    fest_2  organiser_4              NaN
# 1           Aya Kennedy  18XJ1A0107    fest_2  organiser_1              NaN
# 2     Genevieve Ratliff  18XJ1A0114    fest_1  organiser_5              NaN
# 3         Starr Hammond  18XJ1A0134    fest_2  organiser_2              NaN
# 4        Evelin Bradley  18XJ1A0188    fest_1  organiser_1              NaN
# ...                 ...         ...       ...          ...              ...
# 4665       Natalia Huff  17XJ1A0349    fest_1  Participant  fest_1_event_13
# 4666       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_4
# 4667       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_3
# 4668       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_8
# 4669       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_5
#
#       participated
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 4665          True
# 4666          True
# 4667          True
# 4668          True
# 4669          True
#
# [4670 rows x 6 columns]

# %% [markdown]
# dropping all persons who are not in any fest

# %% [markdown]
# marking events for first 20 none

# %%
for i in range(0,20):
    df_onlyfest['Event'][i]='none'
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# df_onlyfest['Event']=df_onlyfest['Event'].astype(str)
# for index,rows in df_onlyfest.iterrows():
#     if len(rows['Event']==0):
#         df_onlytest.drop(index,inplace=True)

# %%
df_newfest=df_onlyfest.dropna()
df_newfest
# Out:
#                    Name          ID Fest_Name         Role            Event  \
# 0         Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 1           Aya Kennedy  18XJ1A0107    fest_2  organiser_1             none
# 2     Genevieve Ratliff  18XJ1A0114    fest_1  organiser_5             none
# 3         Starr Hammond  18XJ1A0134    fest_2  organiser_2             none
# 4        Evelin Bradley  18XJ1A0188    fest_1  organiser_1             none
# ...                 ...         ...       ...          ...              ...
# 4665       Natalia Huff  17XJ1A0349    fest_1  Participant  fest_1_event_13
# 4666       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_4
# 4667       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_3
# 4668       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_8
# 4669       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_5
#
#       participated
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 4665          True
# 4666          True
# 4667          True
# 4668          True
# 4669          True
#
# [4555 rows x 6 columns]

# %%
# df_onlyfest=df_onlyfest.fillna('none')

# %%
df_onlyfest
# Out:
#                    Name          ID Fest_Name         Role            Event  \
# 0         Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 1           Aya Kennedy  18XJ1A0107    fest_2  organiser_1             none
# 2     Genevieve Ratliff  18XJ1A0114    fest_1  organiser_5             none
# 3         Starr Hammond  18XJ1A0134    fest_2  organiser_2             none
# 4        Evelin Bradley  18XJ1A0188    fest_1  organiser_1             none
# ...                 ...         ...       ...          ...              ...
# 4665       Natalia Huff  17XJ1A0349    fest_1  Participant  fest_1_event_13
# 4666       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_4
# 4667       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_3
# 4668       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_8
# 4669       Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_5
#
#       participated
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 4665          True
# 4666          True
# 4667          True
# 4668          True
# 4669          True
#
# [4670 rows x 6 columns]

# %%
df_metaclub['Name'].value_counts()
# Out:
# Annette Ahmed        16
# Jaquelin Duran       14
# Irvin Lira           10
# Litzy Moyer           9
# Javier Breaux         9
#                      ..
# Charlotte Lorenzo     1
# Devyn Ewing           1
# Thea McCloud          1
# Serenity Ngo          1
# Nestor Light          1
# Name: Name, Length: 260, dtype: int64

# %%
df_metaclub.isnull().sum()
# Out:
# Name           0
# ID             0
# Club_Name    240
# Event        240
# Role         240
# dtype: int64

# %%
# df_metaclub['Role']=df_metaclub['Role'].astype(str)
# for index,row in df_metaclub.iterrows():
#     if len(row['Role'])==0:
#         df_metaclub.drop(index,inplace=True,axis=0)
# df_metaclub.isnull().sum()
df_metaclub=df_metaclub.dropna()

# %%
df_metaclub
# Out:
#                 Name          ID Club_Name           Event         Role
# 0      Annette Ahmed  18XJ1A0100    club_2  club_2_event_2  Participant
# 1      Annette Ahmed  18XJ1A0100    club_1  club_1_event_1  organiser_1
# 2      Annette Ahmed  18XJ1A0100    club_1  club_1_event_2  Participant
# 3      Annette Ahmed  18XJ1A0100    club_1  club_1_event_2  organiser_1
# 4      Annette Ahmed  18XJ1A0100    club_1  club_1_event_3  Participant
# ...              ...         ...       ...             ...          ...
# 1229  Joselyn Barrow  17XJ1A0347    club_1  club_1_event_3  Participant
# 1230    Yisroel Sisk  17XJ1A0348    club_1  club_1_event_1  Participant
# 1231    Yisroel Sisk  17XJ1A0348    club_2  club_2_event_1  Participant
# 1232    Yisroel Sisk  17XJ1A0348    club_2  club_2_event_2  Participant
# 1233    Yisroel Sisk  17XJ1A0348    club_3  club_3_event_1  Participant
#
# [995 rows x 5 columns]

# %%
club_1=0
club_2=0
club_3=0
for index,row in df_metaclub.iterrows():
    if row['Club_Name']=='club_1' and row['Role']=='Participant':
        club_1=club_1+1
    elif row['Club_Name']=='club_2' and row['Role']=='Participant':
        club_2=club_2+1
    elif row['Club_Name']=='club_3' and row['Role']=='Participant':
        club_3=club_3+1
print(club_1)
print(club_2)
print(club_3)
# Out:
# 317
# 319
# 317

# %%
df_metaclub['Role'].value_counts()
# Out:
# Participant    953
# organiser_1      9
# organiser_3      9
# organiser_5      8
# organiser_2      8
# organiser_4      8
# Name: Role, dtype: int64

# %%
fest_1=0
fest_2=0

for index,row in df_onlyfest.iterrows():
    if row['Fest_Name']=='fest_1' and row['Role']=='Participant':
        fest_1=fest_1+1
    elif row['Fest_Name']=='fest_2' and row['Role']=='Participant':
        fest_2=fest_2+1
#     elif row['Club_Name']=='club_3' and row['Role']=='Participant':
#         club_3=club_3+1
print(fest_1)
print(fest_2)
# print(club_3)
# Out:
# 1912
# 2623

# %% [markdown]
# clearly we can see that there are more people perticipating in fests rather than club activities
# 953 participants and 42 organisers

# %%
df_onlyfest['Role'].value_counts()
# Out:
# Participant     4650
# organiser_4        2
# organiser_1        2
# organiser_5        2
# organiser_2        2
# organiser_3        2
# organiser_6        2
# organiser_7        2
# organiser_8        2
# organiser_9        2
# organiser_10       2
# Name: Role, dtype: int64

# %%
df_onlyfest['Name'].value_counts()
# Out:
# Keyara Camacho     54
# Jaquelin Duran     50
# Zachery Clancy     49
# Annette Ahmed      41
# Branson Harman     40
#                    ..
# Ciera Almanza       1
# Lewis Breedlove     1
# Katelynn Harlow     1
# Shea Jenkins        1
# Kobe Barrientos     1
# Name: Name, Length: 500, dtype: int64

# %% [markdown]
# 4650 participants in fests and 20 organisers for total events

# %%
df_onlyfest['Event'].value_counts()
# Out:
# fest_1_event_3     210
# fest_2_event_4     210
# fest_2_event_2     210
# fest_1_event_4     208
# fest_2_event_5     208
# fest_1_event_5     208
# fest_2_event_1     208
# fest_1_event_2     207
# fest_1_event_1     207
# fest_2_event_3     201
# fest_2_event_10    142
# fest_2_event_14    141
# fest_2_event_7     140
# fest_1_event_7     140
# fest_2_event_9     139
# fest_1_event_6     139
# fest_2_event_11    139
# fest_2_event_8     137
# fest_1_event_9     136
# fest_2_event_12    136
# fest_2_event_13    136
# fest_1_event_10    135
# fest_2_event_15    135
# fest_1_event_13    135
# fest_2_event_6     134
# fest_1_event_8     133
# fest_1_event_12    131
# fest_1_event_11    130
# none                20
# Name: Event, dtype: int64

# %% [markdown]
# **we can see that even after having less no.of participants clubs are  having more no.of organizers than the no.of organizers in fests, even the participation is less in club events compared to fests**

# %% [markdown]
# **defining club heads depending on participation in events**

# %%
df_common=pd.merge(df_onlyfest,df_metaclub,how='left',on=['Name','ID'])
df_common
# Out:
#                Name          ID Fest_Name       Role_x          Event_x  \
# 0     Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 1     Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 2     Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 3     Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# 4     Annette Ahmed  18XJ1A0100    fest_2  organiser_4             none
# ...             ...         ...       ...          ...              ...
# 9163   Natalia Huff  17XJ1A0349    fest_1  Participant  fest_1_event_13
# 9164   Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_4
# 9165   Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_3
# 9166   Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_8
# 9167   Natalia Huff  17XJ1A0349    fest_1  Participant   fest_1_event_5
#
#       participated Club_Name         Event_y       Role_y
# 0            False    club_2  club_2_event_2  Participant
# 1            False    club_1  club_1_event_1  organiser_1
# 2            False    club_1  club_1_event_2  Participant
# 3            False    club_1  club_1_event_2  organiser_1
# 4            False    club_1  club_1_event_3  Participant
# ...            ...       ...             ...          ...
# 9163          True       NaN             NaN          NaN
# 9164          True       NaN             NaN          NaN
# 9165          True       NaN             NaN          NaN
# 9166          True       NaN             NaN          NaN
# 9167          True       NaN             NaN          NaN
#
# [9168 rows x 9 columns]

# %%
df_common.dropna()
# Out:
#                Name          ID Fest_Name       Role_x         Event_x  \
# 0     Annette Ahmed  18XJ1A0100    fest_2  organiser_4            none
# 1     Annette Ahmed  18XJ1A0100    fest_2  organiser_4            none
# 2     Annette Ahmed  18XJ1A0100    fest_2  organiser_4            none
# 3     Annette Ahmed  18XJ1A0100    fest_2  organiser_4            none
# 4     Annette Ahmed  18XJ1A0100    fest_2  organiser_4            none
# ...             ...         ...       ...          ...             ...
# 9148   Yisroel Sisk  17XJ1A0348    fest_2  Participant  fest_2_event_4
# 9149   Yisroel Sisk  17XJ1A0348    fest_2  Participant  fest_1_event_2
# 9150   Yisroel Sisk  17XJ1A0348    fest_2  Participant  fest_1_event_2
# 9151   Yisroel Sisk  17XJ1A0348    fest_2  Participant  fest_1_event_2
# 9152   Yisroel Sisk  17XJ1A0348    fest_2  Participant  fest_1_event_2
#
#       participated Club_Name         Event_y       Role_y
# 0            False    club_2  club_2_event_2  Participant
# 1            False    club_1  club_1_event_1  organiser_1
# 2            False    club_1  club_1_event_2  Participant
# 3            False    club_1  club_1_event_2  organiser_1
# 4            False    club_1  club_1_event_3  Participant
# ...            ...       ...             ...          ...
# 9148          True    club_3  club_3_event_1  Participant
# 9149          True    club_1  club_1_event_1  Participant
# 9150          True    club_2  club_2_event_1  Participant
# 9151          True    club_2  club_2_event_2  Participant
# 9152          True    club_3  club_3_event_1  Participant
#
# [5644 rows x 9 columns]

# %%
df_common['Name'].value_counts()
# Out:
# Jaquelin Duran       700
# Annette Ahmed        656
# Zachery Clancy       392
# Keyara Camacho       270
# Irvin Lira           170
#                     ...
# Tori Seibert           1
# Maximilian McGraw      1
# Annalee Simmons        1
# Cameron Burleson       1
# Trista Pritchard       1
# Name: Name, Length: 500, dtype: int64
